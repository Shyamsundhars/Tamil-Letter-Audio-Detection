# %%
# !pip install numpy pandas librosa scikit-learn tensorflow sounddevice matplotlib
# Out:
# Requirement already satisfied: numpy in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)
# Requirement already satisfied: librosa in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.10.2.post1)
# Requirement already satisfied: scikit-learn in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.5.1)
# Requirement already satisfied: tensorflow in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.17.0)
# Requirement already satisfied: sounddevice in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.0)
# Requirement already satisfied: matplotlib in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.1.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.14.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (4.8.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: pycparser in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from CFFI>=1.0->sounddevice) (2.22)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)

# %%
import os
import numpy as np
import librosa

# Configuration
SAMPLE_RATE = 16000
N_FFT = 256  # Reduced n_fft size to handle shorter signals better
DATASET_PATH = "audio_dataset"  # Root folder containing subdirectories for each letter

def load_audio_files(dataset_path):
    
    x_data = []
    y_data = []

    # List all subdirectories in the dataset path (each representing a Tamil letter)
    labels = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]
    print(f"Detected labels (directories): {labels}")  # Debug: List detected directories

    for label in labels:
        class_path = os.path.join(dataset_path, label)  # e.g., "audio_dataset/அ"
        print(f"Processing directory: {class_path}")  # Debug: Print each directory being processed
        
        # Iterate through each audio file in the class directory
        for file_name in os.listdir(class_path):
            file_path = os.path.join(class_path, file_name)
            print(f"Checking file: {file_path}")  # Debug: Print each file path being checked
            
            # Ensure the path is a file and ends with .wav
            if os.path.isfile(file_path) and file_path.endswith('.wav'):
                print(f"Loading file: {file_path}")  # Debug: Confirm file is being loaded
                
                # Load the audio file
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
                
                # If the signal is too short, pad it with zeros
                if len(signal) < N_FFT:
                    padding = N_FFT - len(signal)
                    signal = np.pad(signal, (0, padding), 'constant')
                
                # Extract MFCC features with a reduced n_fft size
                mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=N_FFT)
                mfccs_mean = np.mean(mfccs.T, axis=0)  # Averaging MFCCs

                x_data.append(mfccs_mean)
                y_data.append(label)  # Append the label (e.g., 'அ')
            else:
                print(f"Skipped: {file_path} is not a valid .wav file.")  # Debug: Skip message for invalid files
    
    return np.array(x_data), np.array(y_data)

# Load the data
x_data, y_data = load_audio_files(DATASET_PATH)
print(f"Loaded {len(x_data)} audio files.")

# %%
# Function to extract MFCC features from audio signals
def extract_mfcc(signal, sample_rate, n_mfcc=13):
    mfccs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=n_mfcc)
    mfccs = np.mean(mfccs.T, axis=0)  # Flatten MFCC matrix to a single vector
    return mfccs

# Extract MFCC features for each signal in the dataset
x_features = np.array([extract_mfcc(signal, SAMPLE_RATE) for signal in x_data])
print(f"Extracted MFCC features from {len(x_features)} audio files.")

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Encode the class labels into numeric form
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_data)
y_categorical = to_categorical(y_encoded)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_features, y_categorical, test_size=0.2, random_state=42)

# Build a simple neural network model
model = Sequential([
    Dense(256, input_shape=(x_train.shape[1],), activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer with softmax activation
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32)

# Save the trained model
model.save('tamil_uyir_recognition_model.keras')

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# Encode the class labels into numeric form
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_data)
y_categorical = to_categorical(y_encoded)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_features, y_categorical, test_size=0.2, random_state=42)

# Build a more advanced neural network model
model = Sequential()

# First Dense Layer with Batch Normalization and Dropout
model.add(Dense(256, input_shape=(x_train.shape[1],), activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Second Dense Layer with Batch Normalization and Dropout
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Third Dense Layer with Batch Normalization and Dropout
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Output layer with softmax activation
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

# Compile the model with the Adam optimizer and learning rate scheduler
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32, callbacks=[reduce_lr])

# Save the trained model
model.save('tamil_uyir_recognition_model_advanced.keras')

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# %%
import sounddevice as sd

# Function to predict the letter from an audio signal
def predict_letter(audio_signal):
    features = extract_mfcc(audio_signal, SAMPLE_RATE).reshape(1, -1)  # Extract features and reshape for the model
    prediction = model.predict(features)  # Predict the letter
    predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])  # Convert prediction to label
    return predicted_label[0]

# Function to record audio and predict the letter
def record_and_predict(duration=1):
    print("Recording...")
    audio_signal = sd.rec(int(duration * SAMPLE_RATE), samplerate=SAMPLE_RATE, channels=1, dtype='float32')
    sd.wait()  # Wait for recording to finish
    audio_signal = audio_signal.flatten()  # Flatten to a 1D array
    predicted_letter = predict_letter(audio_signal)
    print(f"Recognized Tamil Uyir Letter: {predicted_letter}")

# Test the real-time recognition
record_and_predict()

# %%
import os
import numpy as np
import librosa
import sounddevice as sd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# Configuration
SAMPLE_RATE = 22050
N_FFT = 256  # Reduced n_fft size to handle shorter signals better
DATASET_PATH = "audio_dataset"  # Root folder containing subdirectories for each letter

def load_audio_files(dataset_path):
    x_data = []
    y_data = []

    # List all subdirectories in the dataset path (each representing a Tamil letter)
    labels = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]
    print(f"Detected labels (directories): {labels}")

    for label in labels:
        class_path = os.path.join(dataset_path, label)
        print(f"Processing directory: {class_path}")
        
        # Iterate through each audio file in the class directory
        for file_name in os.listdir(class_path):
            file_path = os.path.join(class_path, file_name)
            print(f"Checking file: {file_path}")
            
            if os.path.isfile(file_path) and file_path.endswith('.wav'):
                print(f"Loading file: {file_path}")
                
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
                
                if len(signal) < N_FFT:
                    padding = N_FFT - len(signal)
                    signal = np.pad(signal, (0, padding), 'constant')
                
                mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=N_FFT)
                mfccs_mean = np.mean(mfccs.T, axis=0)

                x_data.append(mfccs_mean)
                y_data.append(label)
            else:
                print(f"Skipped: {file_path} is not a valid .wav file.")
    
    return np.array(x_data), np.array(y_data)

# Load the data
x_data, y_data = load_audio_files(DATASET_PATH)
print(f"Loaded {len(x_data)} audio files.")

# Function to extract MFCC features from audio signals
#def extract_mfcc(signal, sample_rate, n_mfcc=13):
 #   mfccs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=n_mfcc)
  #  mfccs = np.mean(mfccs.T, axis=0)
   # return mfccs

# Modify n_fft based on the signal length
def extract_mfcc(signal, sample_rate, n_mfcc=13):
    # Use a minimum n_fft of 64 and ensure it's not larger than the signal length
    n_fft = min(max(8, len(signal)), N_FFT)
    #mfccs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=n_mfcc, n_fft=n_fft)
    mfccs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=13, n_fft=n_fft, n_mels=40,fmax=8000)  # Reduce n_mels to 40
    mfccs = np.mean(mfccs.T, axis=0)
    return mfccs

# Extract MFCC features for each signal in the dataset
x_features = np.array([extract_mfcc(signal, SAMPLE_RATE) for signal in x_data])
print(f"Extracted MFCC features from {len(x_features)} audio files.")

# Encode the class labels into numeric form
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_data)
y_categorical = to_categorical(y_encoded)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_features, y_categorical, test_size=0.2, random_state=42)

from tensorflow.keras import Input

model = Sequential()

# Define the input layer separately using Input()
model.add(Input(shape=(x_train.shape[1],)))

# First Dense Layer without input_shape
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Continue with the rest of the model as before
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

# Output layer with softmax activation
model.add(Dense(len(label_encoder.classes_), activation='softmax'))

# Compile the model with the Adam optimizer and learning rate scheduler
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Reduce learning rate when the validation loss plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=0.00001)

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32, callbacks=[reduce_lr])

# Save the trained model
model.save('tamil_uyir_recognition_model_advanced.keras')

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Function to predict the letter from an audio signal and display confidence levels
def predict_letter(audio_signal):
    features = extract_mfcc(audio_signal, SAMPLE_RATE).reshape(1, -1)  # Extract features and reshape for the model
    predictions = model.predict(features)  # Predict the letter probabilities
    predicted_label_index = np.argmax(predictions)  # Get the index of the highest probability
    
    # Get the predicted letter and confidence for each letter
    predicted_letter = label_encoder.inverse_transform([predicted_label_index])[0]
    confidence_levels = predictions[0]  # Extract the confidence levels (probabilities)
    
    # Print the recognized letter
    print(f"Recognized Tamil Uyir Letter: {predicted_letter}")
    
    # Print confidence levels for each letter
    for i, confidence in enumerate(confidence_levels):
        letter = label_encoder.inverse_transform([i])[0]
        print(f"Letter: {letter} - Confidence: {confidence * 100:.2f}%")
    
    return predicted_letter

# Function to record audio and predict the letter
def record_and_predict(duration=1):
    print("Recording...")
    audio_signal = sd.rec(int(duration * SAMPLE_RATE), samplerate=SAMPLE_RATE, channels=1, dtype='float32')
    sd.wait()  # Wait for recording to finish
    audio_signal = audio_signal.flatten()  # Flatten to a 1D array
    predicted_letter = predict_letter(audio_signal)

# Test the real-time recognition with confidence levels
record_and_predict()
# Out:
# Detected labels (directories): ['அ', 'ஆ', 'இ', 'ஈ', 'உ', 'ஊ', 'எ', 'ஏ', 'ஐ', 'ஒ', 'ஓ', 'ஔ']
# Processing directory: audio_dataset\அ
# Checking file: audio_dataset\அ\old
# Skipped: audio_dataset\அ\old is not a valid .wav file.
# Checking file: audio_dataset\அ\அ (1).wav
# Loading file: audio_dataset\அ\அ (1).wav
# Checking file: audio_dataset\அ\அ (10).wav
# Loading file: audio_dataset\அ\அ (10).wav
# Checking file: audio_dataset\அ\அ (11).wav
# Loading file: audio_dataset\அ\அ (11).wav
# Checking file: audio_dataset\அ\அ (12).wav
# Loading file: audio_dataset\அ\அ (12).wav
# Checking file: audio_dataset\அ\அ (13).wav
# Loading file: audio_dataset\அ\அ (13).wav
# Checking file: audio_dataset\அ\அ (14).wav
# Loading file: audio_dataset\அ\அ (14).wav
# Checking file: audio_dataset\அ\அ (15).wav
# Loading file: audio_dataset\அ\அ (15).wav
# Checking file: audio_dataset\அ\அ (16).wav
# Loading file: audio_dataset\அ\அ (16).wav
# Checking file: audio_dataset\அ\அ (17).wav
# Loading file: audio_dataset\அ\அ (17).wav
# Checking file: audio_dataset\அ\அ (18).wav
# Loading file: audio_dataset\அ\அ (18).wav
# Checking file: audio_dataset\அ\அ (19).wav
# Loading file: audio_dataset\அ\அ (19).wav
# Checking file: audio_dataset\அ\அ (2).wav
# Loading file: audio_dataset\அ\அ (2).wav
# Checking file: audio_dataset\அ\அ (20).wav
# Loading file: audio_dataset\அ\அ (20).wav
# Checking file: audio_dataset\அ\அ (21).wav
# Loading file: audio_dataset\அ\அ (21).wav
# Checking file: audio_dataset\அ\அ (22).wav
# Loading file: audio_dataset\அ\அ (22).wav
# Checking file: audio_dataset\அ\அ (23).wav
# Loading file: audio_dataset\அ\அ (23).wav
# Checking file: audio_dataset\அ\அ (24).wav
# Loading file: audio_dataset\அ\அ (24).wav
# Checking file: audio_dataset\அ\அ (25).wav
# Loading file: audio_dataset\அ\அ (25).wav
# Checking file: audio_dataset\அ\அ (26).wav
# Loading file: audio_dataset\அ\அ (26).wav
# Checking file: audio_dataset\அ\அ (27).wav
# Loading file: audio_dataset\அ\அ (27).wav
# Checking file: audio_dataset\அ\அ (28).wav
# Loading file: audio_dataset\அ\அ (28).wav
# Checking file: audio_dataset\அ\அ (29).wav
# Loading file: audio_dataset\அ\அ (29).wav
# Checking file: audio_dataset\அ\அ (3).wav
# Loading file: audio_dataset\அ\அ (3).wav
# Checking file: audio_dataset\அ\அ (30).wav
# Loading file: audio_dataset\அ\அ (30).wav
# Checking file: audio_dataset\அ\அ (31).wav
# Loading file: audio_dataset\அ\அ (31).wav
# Checking file: audio_dataset\அ\அ (32).wav
# Loading file: audio_dataset\அ\அ (32).wav
# Checking file: audio_dataset\அ\அ (33).wav
# Loading file: audio_dataset\அ\அ (33).wav
# Checking file: audio_dataset\அ\அ (34).wav
# Loading file: audio_dataset\அ\அ (34).wav
# Checking file: audio_dataset\அ\அ (35).wav
# Loading file: audio_dataset\அ\அ (35).wav
# Checking file: audio_dataset\அ\அ (36).wav
# Loading file: audio_dataset\அ\அ (36).wav
# Checking file: audio_dataset\அ\அ (37).wav
# Loading file: audio_dataset\அ\அ (37).wav
# Checking file: audio_dataset\அ\அ (38).wav
# Loading file: audio_dataset\அ\அ (38).wav
# Checking file: audio_dataset\அ\அ (39).wav
# Loading file: audio_dataset\அ\அ (39).wav
# Checking file: audio_dataset\அ\அ (4).wav
# Loading file: audio_dataset\அ\அ (4).wav
# Checking file: audio_dataset\அ\அ (40).wav
# Loading file: audio_dataset\அ\அ (40).wav
# Checking file: audio_dataset\அ\அ (41).wav
# Loading file: audio_dataset\அ\அ (41).wav
# Checking file: audio_dataset\அ\அ (42).wav
# Loading file: audio_dataset\அ\அ (42).wav
# Checking file: audio_dataset\அ\அ (43).wav
# Loading file: audio_dataset\அ\அ (43).wav
# Checking file: audio_dataset\அ\அ (44).wav
# Loading file: audio_dataset\அ\அ (44).wav
# Checking file: audio_dataset\அ\அ (45).wav
# Loading file: audio_dataset\அ\அ (45).wav
# Checking file: audio_dataset\அ\அ (46).wav
# Loading file: audio_dataset\அ\அ (46).wav
# Checking file: audio_dataset\அ\அ (47).wav
# Loading file: audio_dataset\அ\அ (47).wav
# Checking file: audio_dataset\அ\அ (48).wav
# Loading file: audio_dataset\அ\அ (48).wav
# Checking file: audio_dataset\அ\அ (49).wav
# Loading file: audio_dataset\அ\அ (49).wav
# Checking file: audio_dataset\அ\அ (5).wav
# Loading file: audio_dataset\அ\அ (5).wav
# Checking file: audio_dataset\அ\அ (50).wav
# Loading file: audio_dataset\அ\அ (50).wav
# Checking file: audio_dataset\அ\அ (6).wav
# Loading file: audio_dataset\அ\அ (6).wav
# Checking file: audio_dataset\அ\அ (7).wav
# Loading file: audio_dataset\அ\அ (7).wav
# Checking file: audio_dataset\அ\அ (8).wav
# Loading file: audio_dataset\அ\அ (8).wav
# Checking file: audio_dataset\அ\அ (9).wav
# Loading file: audio_dataset\அ\அ (9).wav
# Processing directory: audio_dataset\ஆ
# Checking file: audio_dataset\ஆ\old
# Skipped: audio_dataset\ஆ\old is not a valid .wav file.
# Checking file: audio_dataset\ஆ\ஆ (1).wav
# Loading file: audio_dataset\ஆ\ஆ (1).wav
# Checking file: audio_dataset\ஆ\ஆ (10).wav
# Loading file: audio_dataset\ஆ\ஆ (10).wav
# Checking file: audio_dataset\ஆ\ஆ (11).wav
# Loading file: audio_dataset\ஆ\ஆ (11).wav
# Checking file: audio_dataset\ஆ\ஆ (12).wav
# Loading file: audio_dataset\ஆ\ஆ (12).wav
# Checking file: audio_dataset\ஆ\ஆ (13).wav
# Loading file: audio_dataset\ஆ\ஆ (13).wav
# Checking file: audio_dataset\ஆ\ஆ (14).wav
# Loading file: audio_dataset\ஆ\ஆ (14).wav
# Checking file: audio_dataset\ஆ\ஆ (15).wav
# Loading file: audio_dataset\ஆ\ஆ (15).wav
# Checking file: audio_dataset\ஆ\ஆ (16).wav
# Loading file: audio_dataset\ஆ\ஆ (16).wav
# Checking file: audio_dataset\ஆ\ஆ (17).wav
# Loading file: audio_dataset\ஆ\ஆ (17).wav
# Checking file: audio_dataset\ஆ\ஆ (18).wav
# Loading file: audio_dataset\ஆ\ஆ (18).wav
# Checking file: audio_dataset\ஆ\ஆ (19).wav
# Loading file: audio_dataset\ஆ\ஆ (19).wav
# Checking file: audio_dataset\ஆ\ஆ (2).wav
# Loading file: audio_dataset\ஆ\ஆ (2).wav
# Checking file: audio_dataset\ஆ\ஆ (20).wav
# Loading file: audio_dataset\ஆ\ஆ (20).wav
# Checking file: audio_dataset\ஆ\ஆ (21).wav
# Loading file: audio_dataset\ஆ\ஆ (21).wav
# Checking file: audio_dataset\ஆ\ஆ (22).wav
# Loading file: audio_dataset\ஆ\ஆ (22).wav
# Checking file: audio_dataset\ஆ\ஆ (23).wav
# Loading file: audio_dataset\ஆ\ஆ (23).wav
# Checking file: audio_dataset\ஆ\ஆ (24).wav
# Loading file: audio_dataset\ஆ\ஆ (24).wav
# Checking file: audio_dataset\ஆ\ஆ (25).wav
# Loading file: audio_dataset\ஆ\ஆ (25).wav
# Checking file: audio_dataset\ஆ\ஆ (26).wav
# Loading file: audio_dataset\ஆ\ஆ (26).wav
# Checking file: audio_dataset\ஆ\ஆ (27).wav
# Loading file: audio_dataset\ஆ\ஆ (27).wav
# Checking file: audio_dataset\ஆ\ஆ (28).wav
# Loading file: audio_dataset\ஆ\ஆ (28).wav
# Checking file: audio_dataset\ஆ\ஆ (29).wav
# Loading file: audio_dataset\ஆ\ஆ (29).wav
# Checking file: audio_dataset\ஆ\ஆ (3).wav
# Loading file: audio_dataset\ஆ\ஆ (3).wav
# Checking file: audio_dataset\ஆ\ஆ (30).wav
# Loading file: audio_dataset\ஆ\ஆ (30).wav
# Checking file: audio_dataset\ஆ\ஆ (31).wav
# Loading file: audio_dataset\ஆ\ஆ (31).wav
# Checking file: audio_dataset\ஆ\ஆ (32).wav
# Loading file: audio_dataset\ஆ\ஆ (32).wav
# Checking file: audio_dataset\ஆ\ஆ (33).wav
# Loading file: audio_dataset\ஆ\ஆ (33).wav
# Checking file: audio_dataset\ஆ\ஆ (34).wav
# Loading file: audio_dataset\ஆ\ஆ (34).wav
# Checking file: audio_dataset\ஆ\ஆ (35).wav
# Loading file: audio_dataset\ஆ\ஆ (35).wav
# Checking file: audio_dataset\ஆ\ஆ (36).wav
# Loading file: audio_dataset\ஆ\ஆ (36).wav
# Checking file: audio_dataset\ஆ\ஆ (37).wav
# Loading file: audio_dataset\ஆ\ஆ (37).wav
# Checking file: audio_dataset\ஆ\ஆ (38).wav
# Loading file: audio_dataset\ஆ\ஆ (38).wav
# Checking file: audio_dataset\ஆ\ஆ (39).wav
# Loading file: audio_dataset\ஆ\ஆ (39).wav
# Checking file: audio_dataset\ஆ\ஆ (4).wav
# Loading file: audio_dataset\ஆ\ஆ (4).wav
# Checking file: audio_dataset\ஆ\ஆ (40).wav
# Loading file: audio_dataset\ஆ\ஆ (40).wav
# Checking file: audio_dataset\ஆ\ஆ (41).wav
# Loading file: audio_dataset\ஆ\ஆ (41).wav
# Checking file: audio_dataset\ஆ\ஆ (42).wav
# Loading file: audio_dataset\ஆ\ஆ (42).wav
# Checking file: audio_dataset\ஆ\ஆ (43).wav
# Loading file: audio_dataset\ஆ\ஆ (43).wav
# Checking file: audio_dataset\ஆ\ஆ (44).wav
# Loading file: audio_dataset\ஆ\ஆ (44).wav
# Checking file: audio_dataset\ஆ\ஆ (45).wav
# Loading file: audio_dataset\ஆ\ஆ (45).wav
# Checking file: audio_dataset\ஆ\ஆ (46).wav
# Loading file: audio_dataset\ஆ\ஆ (46).wav
# Checking file: audio_dataset\ஆ\ஆ (47).wav
# Loading file: audio_dataset\ஆ\ஆ (47).wav
# Checking file: audio_dataset\ஆ\ஆ (48).wav
# Loading file: audio_dataset\ஆ\ஆ (48).wav
# Checking file: audio_dataset\ஆ\ஆ (49).wav
# Loading file: audio_dataset\ஆ\ஆ (49).wav
# Checking file: audio_dataset\ஆ\ஆ (5).wav
# Loading file: audio_dataset\ஆ\ஆ (5).wav
# Checking file: audio_dataset\ஆ\ஆ (50).wav
# Loading file: audio_dataset\ஆ\ஆ (50).wav
# Checking file: audio_dataset\ஆ\ஆ (6).wav
# Loading file: audio_dataset\ஆ\ஆ (6).wav
# Checking file: audio_dataset\ஆ\ஆ (7).wav
# Loading file: audio_dataset\ஆ\ஆ (7).wav
# Checking file: audio_dataset\ஆ\ஆ (8).wav
# Loading file: audio_dataset\ஆ\ஆ (8).wav
# Checking file: audio_dataset\ஆ\ஆ (9).wav
# Loading file: audio_dataset\ஆ\ஆ (9).wav
# Processing directory: audio_dataset\இ
# Checking file: audio_dataset\இ\old
# Skipped: audio_dataset\இ\old is not a valid .wav file.
# Checking file: audio_dataset\இ\இ (1).wav
# Loading file: audio_dataset\இ\இ (1).wav
# Checking file: audio_dataset\இ\இ (10).wav
# Loading file: audio_dataset\இ\இ (10).wav
# Checking file: audio_dataset\இ\இ (11).wav
# Loading file: audio_dataset\இ\இ (11).wav
# Checking file: audio_dataset\இ\இ (12).wav
# Loading file: audio_dataset\இ\இ (12).wav
# Checking file: audio_dataset\இ\இ (13).wav
# Loading file: audio_dataset\இ\இ (13).wav
# Checking file: audio_dataset\இ\இ (14).wav
# Loading file: audio_dataset\இ\இ (14).wav
# Checking file: audio_dataset\இ\இ (15).wav
# Loading file: audio_dataset\இ\இ (15).wav
# Checking file: audio_dataset\இ\இ (16).wav
# Loading file: audio_dataset\இ\இ (16).wav
# Checking file: audio_dataset\இ\இ (17).wav
# Loading file: audio_dataset\இ\இ (17).wav
# Checking file: audio_dataset\இ\இ (18).wav
# Loading file: audio_dataset\இ\இ (18).wav
# Checking file: audio_dataset\இ\இ (19).wav
# Loading file: audio_dataset\இ\இ (19).wav
# Checking file: audio_dataset\இ\இ (2).wav
# Loading file: audio_dataset\இ\இ (2).wav
# Checking file: audio_dataset\இ\இ (20).wav
# Loading file: audio_dataset\இ\இ (20).wav
# Checking file: audio_dataset\இ\இ (21).wav
# Loading file: audio_dataset\இ\இ (21).wav
# Checking file: audio_dataset\இ\இ (22).wav
# Loading file: audio_dataset\இ\இ (22).wav
# Checking file: audio_dataset\இ\இ (23).wav
# Loading file: audio_dataset\இ\இ (23).wav
# Checking file: audio_dataset\இ\இ (24).wav
# Loading file: audio_dataset\இ\இ (24).wav
# Checking file: audio_dataset\இ\இ (25).wav
# Loading file: audio_dataset\இ\இ (25).wav
# Checking file: audio_dataset\இ\இ (26).wav
# Loading file: audio_dataset\இ\இ (26).wav
# Checking file: audio_dataset\இ\இ (27).wav
# Loading file: audio_dataset\இ\இ (27).wav
# Checking file: audio_dataset\இ\இ (28).wav
# Loading file: audio_dataset\இ\இ (28).wav
# Checking file: audio_dataset\இ\இ (29).wav
# Loading file: audio_dataset\இ\இ (29).wav
# Checking file: audio_dataset\இ\இ (3).wav
# Loading file: audio_dataset\இ\இ (3).wav
# Checking file: audio_dataset\இ\இ (30).wav
# Loading file: audio_dataset\இ\இ (30).wav
# Checking file: audio_dataset\இ\இ (31).wav
# Loading file: audio_dataset\இ\இ (31).wav
# Checking file: audio_dataset\இ\இ (32).wav
# Loading file: audio_dataset\இ\இ (32).wav
# Checking file: audio_dataset\இ\இ (33).wav
# Loading file: audio_dataset\இ\இ (33).wav
# Checking file: audio_dataset\இ\இ (34).wav
# Loading file: audio_dataset\இ\இ (34).wav
# Checking file: audio_dataset\இ\இ (35).wav
# Loading file: audio_dataset\இ\இ (35).wav
# Checking file: audio_dataset\இ\இ (36).wav
# Loading file: audio_dataset\இ\இ (36).wav
# Checking file: audio_dataset\இ\இ (37).wav
# Loading file: audio_dataset\இ\இ (37).wav
# Checking file: audio_dataset\இ\இ (38).wav
# Loading file: audio_dataset\இ\இ (38).wav
# Checking file: audio_dataset\இ\இ (39).wav
# Loading file: audio_dataset\இ\இ (39).wav
# Checking file: audio_dataset\இ\இ (4).wav
# Loading file: audio_dataset\இ\இ (4).wav
# Checking file: audio_dataset\இ\இ (40).wav
# Loading file: audio_dataset\இ\இ (40).wav
# Checking file: audio_dataset\இ\இ (41).wav
# Loading file: audio_dataset\இ\இ (41).wav
# Checking file: audio_dataset\இ\இ (42).wav
# Loading file: audio_dataset\இ\இ (42).wav
# Checking file: audio_dataset\இ\இ (43).wav
# Loading file: audio_dataset\இ\இ (43).wav
# Checking file: audio_dataset\இ\இ (44).wav
# Loading file: audio_dataset\இ\இ (44).wav
# Checking file: audio_dataset\இ\இ (45).wav
# Loading file: audio_dataset\இ\இ (45).wav
# Checking file: audio_dataset\இ\இ (46).wav
# Loading file: audio_dataset\இ\இ (46).wav
# Checking file: audio_dataset\இ\இ (47).wav
# Loading file: audio_dataset\இ\இ (47).wav
# Checking file: audio_dataset\இ\இ (48).wav
# Loading file: audio_dataset\இ\இ (48).wav
# Checking file: audio_dataset\இ\இ (49).wav
# Loading file: audio_dataset\இ\இ (49).wav
# Checking file: audio_dataset\இ\இ (5).wav
# Loading file: audio_dataset\இ\இ (5).wav
# Checking file: audio_dataset\இ\இ (50).wav
# Loading file: audio_dataset\இ\இ (50).wav
# Checking file: audio_dataset\இ\இ (6).wav
# Loading file: audio_dataset\இ\இ (6).wav
# Checking file: audio_dataset\இ\இ (7).wav
# Loading file: audio_dataset\இ\இ (7).wav
# Checking file: audio_dataset\இ\இ (8).wav
# Loading file: audio_dataset\இ\இ (8).wav
# Checking file: audio_dataset\இ\இ (9).wav
# Loading file: audio_dataset\இ\இ (9).wav
# Processing directory: audio_dataset\ஈ
# Checking file: audio_dataset\ஈ\old
# Skipped: audio_dataset\ஈ\old is not a valid .wav file.
# Checking file: audio_dataset\ஈ\ஈ (1).wav
# Loading file: audio_dataset\ஈ\ஈ (1).wav
# Checking file: audio_dataset\ஈ\ஈ (10).wav
# Loading file: audio_dataset\ஈ\ஈ (10).wav
# Checking file: audio_dataset\ஈ\ஈ (11).wav
# Loading file: audio_dataset\ஈ\ஈ (11).wav
# Checking file: audio_dataset\ஈ\ஈ (12).wav
# Loading file: audio_dataset\ஈ\ஈ (12).wav
# Checking file: audio_dataset\ஈ\ஈ (13).wav
# Loading file: audio_dataset\ஈ\ஈ (13).wav
# Checking file: audio_dataset\ஈ\ஈ (14).wav
# Loading file: audio_dataset\ஈ\ஈ (14).wav
# Checking file: audio_dataset\ஈ\ஈ (15).wav
# Loading file: audio_dataset\ஈ\ஈ (15).wav
# Checking file: audio_dataset\ஈ\ஈ (16).wav
# Loading file: audio_dataset\ஈ\ஈ (16).wav
# Checking file: audio_dataset\ஈ\ஈ (17).wav
# Loading file: audio_dataset\ஈ\ஈ (17).wav
# Checking file: audio_dataset\ஈ\ஈ (18).wav
# Loading file: audio_dataset\ஈ\ஈ (18).wav
# Checking file: audio_dataset\ஈ\ஈ (19).wav
# Loading file: audio_dataset\ஈ\ஈ (19).wav
# Checking file: audio_dataset\ஈ\ஈ (2).wav
# Loading file: audio_dataset\ஈ\ஈ (2).wav
# Checking file: audio_dataset\ஈ\ஈ (20).wav
# Loading file: audio_dataset\ஈ\ஈ (20).wav
# Checking file: audio_dataset\ஈ\ஈ (21).wav
# Loading file: audio_dataset\ஈ\ஈ (21).wav
# Checking file: audio_dataset\ஈ\ஈ (22).wav
# Loading file: audio_dataset\ஈ\ஈ (22).wav
# Checking file: audio_dataset\ஈ\ஈ (23).wav
# Loading file: audio_dataset\ஈ\ஈ (23).wav
# Checking file: audio_dataset\ஈ\ஈ (24).wav
# Loading file: audio_dataset\ஈ\ஈ (24).wav
# Checking file: audio_dataset\ஈ\ஈ (25).wav
# Loading file: audio_dataset\ஈ\ஈ (25).wav
# Checking file: audio_dataset\ஈ\ஈ (26).wav
# Loading file: audio_dataset\ஈ\ஈ (26).wav
# Checking file: audio_dataset\ஈ\ஈ (27).wav
# Loading file: audio_dataset\ஈ\ஈ (27).wav
# Checking file: audio_dataset\ஈ\ஈ (28).wav
# Loading file: audio_dataset\ஈ\ஈ (28).wav
# Checking file: audio_dataset\ஈ\ஈ (29).wav
# Loading file: audio_dataset\ஈ\ஈ (29).wav
# Checking file: audio_dataset\ஈ\ஈ (3).wav
# Loading file: audio_dataset\ஈ\ஈ (3).wav
# Checking file: audio_dataset\ஈ\ஈ (30).wav
# Loading file: audio_dataset\ஈ\ஈ (30).wav
# Checking file: audio_dataset\ஈ\ஈ (31).wav
# Loading file: audio_dataset\ஈ\ஈ (31).wav
# Checking file: audio_dataset\ஈ\ஈ (32).wav
# Loading file: audio_dataset\ஈ\ஈ (32).wav
# Checking file: audio_dataset\ஈ\ஈ (33).wav
# Loading file: audio_dataset\ஈ\ஈ (33).wav
# Checking file: audio_dataset\ஈ\ஈ (34).wav
# Loading file: audio_dataset\ஈ\ஈ (34).wav
# Checking file: audio_dataset\ஈ\ஈ (35).wav
# Loading file: audio_dataset\ஈ\ஈ (35).wav
# Checking file: audio_dataset\ஈ\ஈ (36).wav
# Loading file: audio_dataset\ஈ\ஈ (36).wav
# Checking file: audio_dataset\ஈ\ஈ (37).wav
# Loading file: audio_dataset\ஈ\ஈ (37).wav
# Checking file: audio_dataset\ஈ\ஈ (38).wav
# Loading file: audio_dataset\ஈ\ஈ (38).wav
# Checking file: audio_dataset\ஈ\ஈ (39).wav
# Loading file: audio_dataset\ஈ\ஈ (39).wav
# Checking file: audio_dataset\ஈ\ஈ (4).wav
# Loading file: audio_dataset\ஈ\ஈ (4).wav
# Checking file: audio_dataset\ஈ\ஈ (40).wav
# Loading file: audio_dataset\ஈ\ஈ (40).wav
# Checking file: audio_dataset\ஈ\ஈ (41).wav
# Loading file: audio_dataset\ஈ\ஈ (41).wav
# Checking file: audio_dataset\ஈ\ஈ (42).wav
# Loading file: audio_dataset\ஈ\ஈ (42).wav
# Checking file: audio_dataset\ஈ\ஈ (43).wav
# Loading file: audio_dataset\ஈ\ஈ (43).wav
# Checking file: audio_dataset\ஈ\ஈ (44).wav
# Loading file: audio_dataset\ஈ\ஈ (44).wav
# Checking file: audio_dataset\ஈ\ஈ (45).wav
# Loading file: audio_dataset\ஈ\ஈ (45).wav
# Checking file: audio_dataset\ஈ\ஈ (46).wav
# Loading file: audio_dataset\ஈ\ஈ (46).wav
# Checking file: audio_dataset\ஈ\ஈ (47).wav
# Loading file: audio_dataset\ஈ\ஈ (47).wav
# Checking file: audio_dataset\ஈ\ஈ (48).wav
# Loading file: audio_dataset\ஈ\ஈ (48).wav
# Checking file: audio_dataset\ஈ\ஈ (49).wav
# Loading file: audio_dataset\ஈ\ஈ (49).wav
# Checking file: audio_dataset\ஈ\ஈ (5).wav
# Loading file: audio_dataset\ஈ\ஈ (5).wav
# Checking file: audio_dataset\ஈ\ஈ (50).wav
# Loading file: audio_dataset\ஈ\ஈ (50).wav
# Checking file: audio_dataset\ஈ\ஈ (6).wav
# Loading file: audio_dataset\ஈ\ஈ (6).wav
# Checking file: audio_dataset\ஈ\ஈ (7).wav
# Loading file: audio_dataset\ஈ\ஈ (7).wav
# Checking file: audio_dataset\ஈ\ஈ (8).wav
# Loading file: audio_dataset\ஈ\ஈ (8).wav
# Checking file: audio_dataset\ஈ\ஈ (9).wav
# Loading file: audio_dataset\ஈ\ஈ (9).wav
# Processing directory: audio_dataset\உ
# Checking file: audio_dataset\உ\old
# Skipped: audio_dataset\உ\old is not a valid .wav file.
# Checking file: audio_dataset\உ\உ (1).wav
# Loading file: audio_dataset\உ\உ (1).wav
# Checking file: audio_dataset\உ\உ (10).wav
# Loading file: audio_dataset\உ\உ (10).wav
# Checking file: audio_dataset\உ\உ (11).wav
# Loading file: audio_dataset\உ\உ (11).wav
# Checking file: audio_dataset\உ\உ (12).wav
# Loading file: audio_dataset\உ\உ (12).wav
# Checking file: audio_dataset\உ\உ (13).wav
# Loading file: audio_dataset\உ\உ (13).wav
# Checking file: audio_dataset\உ\உ (14).wav
# Loading file: audio_dataset\உ\உ (14).wav
# Checking file: audio_dataset\உ\உ (15).wav
# Loading file: audio_dataset\உ\உ (15).wav
# Checking file: audio_dataset\உ\உ (16).wav
# Loading file: audio_dataset\உ\உ (16).wav
# Checking file: audio_dataset\உ\உ (17).wav
# Loading file: audio_dataset\உ\உ (17).wav
# Checking file: audio_dataset\உ\உ (18).wav
# Loading file: audio_dataset\உ\உ (18).wav
# Checking file: audio_dataset\உ\உ (19).wav
# Loading file: audio_dataset\உ\உ (19).wav
# Checking file: audio_dataset\உ\உ (2).wav
# Loading file: audio_dataset\உ\உ (2).wav
# Checking file: audio_dataset\உ\உ (20).wav
# Loading file: audio_dataset\உ\உ (20).wav
# Checking file: audio_dataset\உ\உ (21).wav
# Loading file: audio_dataset\உ\உ (21).wav
# Checking file: audio_dataset\உ\உ (22).wav
# Loading file: audio_dataset\உ\உ (22).wav
# Checking file: audio_dataset\உ\உ (23).wav
# Loading file: audio_dataset\உ\உ (23).wav
# Checking file: audio_dataset\உ\உ (24).wav
# Loading file: audio_dataset\உ\உ (24).wav
# Checking file: audio_dataset\உ\உ (25).wav
# Loading file: audio_dataset\உ\உ (25).wav
# Checking file: audio_dataset\உ\உ (26).wav
# Loading file: audio_dataset\உ\உ (26).wav
# Checking file: audio_dataset\உ\உ (27).wav
# Loading file: audio_dataset\உ\உ (27).wav
# Checking file: audio_dataset\உ\உ (28).wav
# Loading file: audio_dataset\உ\உ (28).wav
# Checking file: audio_dataset\உ\உ (29).wav
# Loading file: audio_dataset\உ\உ (29).wav
# Checking file: audio_dataset\உ\உ (3).wav
# Loading file: audio_dataset\உ\உ (3).wav
# Checking file: audio_dataset\உ\உ (30).wav
# Loading file: audio_dataset\உ\உ (30).wav
# Checking file: audio_dataset\உ\உ (31).wav
# Loading file: audio_dataset\உ\உ (31).wav
# Checking file: audio_dataset\உ\உ (32).wav
# Loading file: audio_dataset\உ\உ (32).wav
# Checking file: audio_dataset\உ\உ (33).wav
# Loading file: audio_dataset\உ\உ (33).wav
# Checking file: audio_dataset\உ\உ (34).wav
# Loading file: audio_dataset\உ\உ (34).wav
# Checking file: audio_dataset\உ\உ (35).wav
# Loading file: audio_dataset\உ\உ (35).wav
# Checking file: audio_dataset\உ\உ (36).wav
# Loading file: audio_dataset\உ\உ (36).wav
# Checking file: audio_dataset\உ\உ (37).wav
# Loading file: audio_dataset\உ\உ (37).wav
# Checking file: audio_dataset\உ\உ (38).wav
# Loading file: audio_dataset\உ\உ (38).wav
# Checking file: audio_dataset\உ\உ (39).wav
# Loading file: audio_dataset\உ\உ (39).wav
# Checking file: audio_dataset\உ\உ (4).wav
# Loading file: audio_dataset\உ\உ (4).wav
# Checking file: audio_dataset\உ\உ (40).wav
# Loading file: audio_dataset\உ\உ (40).wav
# Checking file: audio_dataset\உ\உ (41).wav
# Loading file: audio_dataset\உ\உ (41).wav
# Checking file: audio_dataset\உ\உ (42).wav
# Loading file: audio_dataset\உ\உ (42).wav
# Checking file: audio_dataset\உ\உ (43).wav
# Loading file: audio_dataset\உ\உ (43).wav
# Checking file: audio_dataset\உ\உ (44).wav
# Loading file: audio_dataset\உ\உ (44).wav
# Checking file: audio_dataset\உ\உ (45).wav
# Loading file: audio_dataset\உ\உ (45).wav
# Checking file: audio_dataset\உ\உ (46).wav
# Loading file: audio_dataset\உ\உ (46).wav
# Checking file: audio_dataset\உ\உ (47).wav
# Loading file: audio_dataset\உ\உ (47).wav
# Checking file: audio_dataset\உ\உ (48).wav
# Loading file: audio_dataset\உ\உ (48).wav
# Checking file: audio_dataset\உ\உ (49).wav
# Loading file: audio_dataset\உ\உ (49).wav
# Checking file: audio_dataset\உ\உ (5).wav
# Loading file: audio_dataset\உ\உ (5).wav
# Checking file: audio_dataset\உ\உ (50).wav
# Loading file: audio_dataset\உ\உ (50).wav
# Checking file: audio_dataset\உ\உ (6).wav
# Loading file: audio_dataset\உ\உ (6).wav
# Checking file: audio_dataset\உ\உ (7).wav
# Loading file: audio_dataset\உ\உ (7).wav
# Checking file: audio_dataset\உ\உ (8).wav
# Loading file: audio_dataset\உ\உ (8).wav
# Checking file: audio_dataset\உ\உ (9).wav
# Loading file: audio_dataset\உ\உ (9).wav
# Processing directory: audio_dataset\ஊ
# Checking file: audio_dataset\ஊ\old
# Skipped: audio_dataset\ஊ\old is not a valid .wav file.
# Checking file: audio_dataset\ஊ\ஊ (1).wav
# Loading file: audio_dataset\ஊ\ஊ (1).wav
# Checking file: audio_dataset\ஊ\ஊ (10).wav
# Loading file: audio_dataset\ஊ\ஊ (10).wav
# Checking file: audio_dataset\ஊ\ஊ (11).wav
# Loading file: audio_dataset\ஊ\ஊ (11).wav
# Checking file: audio_dataset\ஊ\ஊ (12).wav
# Loading file: audio_dataset\ஊ\ஊ (12).wav
# Checking file: audio_dataset\ஊ\ஊ (13).wav
# Loading file: audio_dataset\ஊ\ஊ (13).wav
# Checking file: audio_dataset\ஊ\ஊ (14).wav
# Loading file: audio_dataset\ஊ\ஊ (14).wav
# Checking file: audio_dataset\ஊ\ஊ (15).wav
# Loading file: audio_dataset\ஊ\ஊ (15).wav
# Checking file: audio_dataset\ஊ\ஊ (16).wav
# Loading file: audio_dataset\ஊ\ஊ (16).wav
# Checking file: audio_dataset\ஊ\ஊ (17).wav
# Loading file: audio_dataset\ஊ\ஊ (17).wav
# Checking file: audio_dataset\ஊ\ஊ (18).wav
# Loading file: audio_dataset\ஊ\ஊ (18).wav
# Checking file: audio_dataset\ஊ\ஊ (19).wav
# Loading file: audio_dataset\ஊ\ஊ (19).wav
# Checking file: audio_dataset\ஊ\ஊ (2).wav
# Loading file: audio_dataset\ஊ\ஊ (2).wav
# Checking file: audio_dataset\ஊ\ஊ (20).wav
# Loading file: audio_dataset\ஊ\ஊ (20).wav
# Checking file: audio_dataset\ஊ\ஊ (21).wav
# Loading file: audio_dataset\ஊ\ஊ (21).wav
# Checking file: audio_dataset\ஊ\ஊ (22).wav
# Loading file: audio_dataset\ஊ\ஊ (22).wav
# Checking file: audio_dataset\ஊ\ஊ (23).wav
# Loading file: audio_dataset\ஊ\ஊ (23).wav
# Checking file: audio_dataset\ஊ\ஊ (24).wav
# Loading file: audio_dataset\ஊ\ஊ (24).wav
# Checking file: audio_dataset\ஊ\ஊ (25).wav
# Loading file: audio_dataset\ஊ\ஊ (25).wav
# Checking file: audio_dataset\ஊ\ஊ (26).wav
# Loading file: audio_dataset\ஊ\ஊ (26).wav
# Checking file: audio_dataset\ஊ\ஊ (27).wav
# Loading file: audio_dataset\ஊ\ஊ (27).wav
# Checking file: audio_dataset\ஊ\ஊ (28).wav
# Loading file: audio_dataset\ஊ\ஊ (28).wav
# Checking file: audio_dataset\ஊ\ஊ (29).wav
# Loading file: audio_dataset\ஊ\ஊ (29).wav
# Checking file: audio_dataset\ஊ\ஊ (3).wav
# Loading file: audio_dataset\ஊ\ஊ (3).wav
# Checking file: audio_dataset\ஊ\ஊ (30).wav
# Loading file: audio_dataset\ஊ\ஊ (30).wav
# Checking file: audio_dataset\ஊ\ஊ (31).wav
# Loading file: audio_dataset\ஊ\ஊ (31).wav
# Checking file: audio_dataset\ஊ\ஊ (32).wav
# Loading file: audio_dataset\ஊ\ஊ (32).wav
# Checking file: audio_dataset\ஊ\ஊ (33).wav
# Loading file: audio_dataset\ஊ\ஊ (33).wav
# Checking file: audio_dataset\ஊ\ஊ (34).wav
# Loading file: audio_dataset\ஊ\ஊ (34).wav
# Checking file: audio_dataset\ஊ\ஊ (35).wav
# Loading file: audio_dataset\ஊ\ஊ (35).wav
# Checking file: audio_dataset\ஊ\ஊ (36).wav
# Loading file: audio_dataset\ஊ\ஊ (36).wav
# Checking file: audio_dataset\ஊ\ஊ (37).wav
# Loading file: audio_dataset\ஊ\ஊ (37).wav
# Checking file: audio_dataset\ஊ\ஊ (38).wav
# Loading file: audio_dataset\ஊ\ஊ (38).wav
# Checking file: audio_dataset\ஊ\ஊ (39).wav
# Loading file: audio_dataset\ஊ\ஊ (39).wav
# Checking file: audio_dataset\ஊ\ஊ (4).wav
# Loading file: audio_dataset\ஊ\ஊ (4).wav
# Checking file: audio_dataset\ஊ\ஊ (40).wav
# Loading file: audio_dataset\ஊ\ஊ (40).wav
# Checking file: audio_dataset\ஊ\ஊ (41).wav
# Loading file: audio_dataset\ஊ\ஊ (41).wav
# Checking file: audio_dataset\ஊ\ஊ (42).wav
# Loading file: audio_dataset\ஊ\ஊ (42).wav
# Checking file: audio_dataset\ஊ\ஊ (43).wav
# Loading file: audio_dataset\ஊ\ஊ (43).wav
# Checking file: audio_dataset\ஊ\ஊ (44).wav
# Loading file: audio_dataset\ஊ\ஊ (44).wav
# Checking file: audio_dataset\ஊ\ஊ (45).wav
# Loading file: audio_dataset\ஊ\ஊ (45).wav
# Checking file: audio_dataset\ஊ\ஊ (46).wav
# Loading file: audio_dataset\ஊ\ஊ (46).wav
# Checking file: audio_dataset\ஊ\ஊ (47).wav
# Loading file: audio_dataset\ஊ\ஊ (47).wav
# Checking file: audio_dataset\ஊ\ஊ (48).wav
# Loading file: audio_dataset\ஊ\ஊ (48).wav
# Checking file: audio_dataset\ஊ\ஊ (49).wav
# Loading file: audio_dataset\ஊ\ஊ (49).wav
# Checking file: audio_dataset\ஊ\ஊ (5).wav
# Loading file: audio_dataset\ஊ\ஊ (5).wav
# Checking file: audio_dataset\ஊ\ஊ (50).wav
# Loading file: audio_dataset\ஊ\ஊ (50).wav
# Checking file: audio_dataset\ஊ\ஊ (6).wav
# Loading file: audio_dataset\ஊ\ஊ (6).wav
# Checking file: audio_dataset\ஊ\ஊ (7).wav
# Loading file: audio_dataset\ஊ\ஊ (7).wav
# Checking file: audio_dataset\ஊ\ஊ (8).wav
# Loading file: audio_dataset\ஊ\ஊ (8).wav
# Checking file: audio_dataset\ஊ\ஊ (9).wav
# Loading file: audio_dataset\ஊ\ஊ (9).wav
# Processing directory: audio_dataset\எ
# Checking file: audio_dataset\எ\old
# Skipped: audio_dataset\எ\old is not a valid .wav file.
# Checking file: audio_dataset\எ\எ (1).wav
# Loading file: audio_dataset\எ\எ (1).wav
# Checking file: audio_dataset\எ\எ (10).wav
# Loading file: audio_dataset\எ\எ (10).wav
# Checking file: audio_dataset\எ\எ (11).wav
# Loading file: audio_dataset\எ\எ (11).wav
# Checking file: audio_dataset\எ\எ (12).wav
# Loading file: audio_dataset\எ\எ (12).wav
# Checking file: audio_dataset\எ\எ (13).wav
# Loading file: audio_dataset\எ\எ (13).wav
# Checking file: audio_dataset\எ\எ (14).wav
# Loading file: audio_dataset\எ\எ (14).wav
# Checking file: audio_dataset\எ\எ (15).wav
# Loading file: audio_dataset\எ\எ (15).wav
# Checking file: audio_dataset\எ\எ (16).wav
# Loading file: audio_dataset\எ\எ (16).wav
# Checking file: audio_dataset\எ\எ (17).wav
# Loading file: audio_dataset\எ\எ (17).wav
# Checking file: audio_dataset\எ\எ (18).wav
# Loading file: audio_dataset\எ\எ (18).wav
# Checking file: audio_dataset\எ\எ (19).wav
# Loading file: audio_dataset\எ\எ (19).wav
# Checking file: audio_dataset\எ\எ (2).wav
# Loading file: audio_dataset\எ\எ (2).wav
# Checking file: audio_dataset\எ\எ (20).wav
# Loading file: audio_dataset\எ\எ (20).wav
# Checking file: audio_dataset\எ\எ (21).wav
# Loading file: audio_dataset\எ\எ (21).wav
# Checking file: audio_dataset\எ\எ (22).wav
# Loading file: audio_dataset\எ\எ (22).wav
# Checking file: audio_dataset\எ\எ (23).wav
# Loading file: audio_dataset\எ\எ (23).wav
# Checking file: audio_dataset\எ\எ (24).wav
# Loading file: audio_dataset\எ\எ (24).wav
# Checking file: audio_dataset\எ\எ (25).wav
# Loading file: audio_dataset\எ\எ (25).wav
# Checking file: audio_dataset\எ\எ (26).wav
# Loading file: audio_dataset\எ\எ (26).wav
# Checking file: audio_dataset\எ\எ (27).wav
# Loading file: audio_dataset\எ\எ (27).wav
# Checking file: audio_dataset\எ\எ (28).wav
# Loading file: audio_dataset\எ\எ (28).wav
# Checking file: audio_dataset\எ\எ (29).wav
# Loading file: audio_dataset\எ\எ (29).wav
# Checking file: audio_dataset\எ\எ (3).wav
# Loading file: audio_dataset\எ\எ (3).wav
# Checking file: audio_dataset\எ\எ (30).wav
# Loading file: audio_dataset\எ\எ (30).wav
# Checking file: audio_dataset\எ\எ (31).wav
# Loading file: audio_dataset\எ\எ (31).wav
# Checking file: audio_dataset\எ\எ (32).wav
# Loading file: audio_dataset\எ\எ (32).wav
# Checking file: audio_dataset\எ\எ (33).wav
# Loading file: audio_dataset\எ\எ (33).wav
# Checking file: audio_dataset\எ\எ (34).wav
# Loading file: audio_dataset\எ\எ (34).wav
# Checking file: audio_dataset\எ\எ (35).wav
# Loading file: audio_dataset\எ\எ (35).wav
# Checking file: audio_dataset\எ\எ (36).wav
# Loading file: audio_dataset\எ\எ (36).wav
# Checking file: audio_dataset\எ\எ (37).wav
# Loading file: audio_dataset\எ\எ (37).wav
# Checking file: audio_dataset\எ\எ (38).wav
# Loading file: audio_dataset\எ\எ (38).wav
# Checking file: audio_dataset\எ\எ (39).wav
# Loading file: audio_dataset\எ\எ (39).wav
# Checking file: audio_dataset\எ\எ (4).wav
# Loading file: audio_dataset\எ\எ (4).wav
# Checking file: audio_dataset\எ\எ (40).wav
# Loading file: audio_dataset\எ\எ (40).wav
# Checking file: audio_dataset\எ\எ (41).wav
# Loading file: audio_dataset\எ\எ (41).wav
# Checking file: audio_dataset\எ\எ (42).wav
# Loading file: audio_dataset\எ\எ (42).wav
# Checking file: audio_dataset\எ\எ (43).wav
# Loading file: audio_dataset\எ\எ (43).wav
# Checking file: audio_dataset\எ\எ (44).wav
# Loading file: audio_dataset\எ\எ (44).wav
# Checking file: audio_dataset\எ\எ (45).wav
# Loading file: audio_dataset\எ\எ (45).wav
# Checking file: audio_dataset\எ\எ (46).wav
# Loading file: audio_dataset\எ\எ (46).wav
# Checking file: audio_dataset\எ\எ (47).wav
# Loading file: audio_dataset\எ\எ (47).wav
# Checking file: audio_dataset\எ\எ (48).wav
# Loading file: audio_dataset\எ\எ (48).wav
# Checking file: audio_dataset\எ\எ (49).wav
# Loading file: audio_dataset\எ\எ (49).wav
# Checking file: audio_dataset\எ\எ (5).wav
# Loading file: audio_dataset\எ\எ (5).wav
# Checking file: audio_dataset\எ\எ (50).wav
# Loading file: audio_dataset\எ\எ (50).wav
# Checking file: audio_dataset\எ\எ (6).wav
# Loading file: audio_dataset\எ\எ (6).wav
# Checking file: audio_dataset\எ\எ (7).wav
# Loading file: audio_dataset\எ\எ (7).wav
# Checking file: audio_dataset\எ\எ (8).wav
# Loading file: audio_dataset\எ\எ (8).wav
# Checking file: audio_dataset\எ\எ (9).wav
# Loading file: audio_dataset\எ\எ (9).wav
# Processing directory: audio_dataset\ஏ
# Checking file: audio_dataset\ஏ\old
# Skipped: audio_dataset\ஏ\old is not a valid .wav file.
# Checking file: audio_dataset\ஏ\ஏ (1).wav
# Loading file: audio_dataset\ஏ\ஏ (1).wav
# Checking file: audio_dataset\ஏ\ஏ (10).wav
# Loading file: audio_dataset\ஏ\ஏ (10).wav
# Checking file: audio_dataset\ஏ\ஏ (11).wav
# Loading file: audio_dataset\ஏ\ஏ (11).wav
# Checking file: audio_dataset\ஏ\ஏ (12).wav
# Loading file: audio_dataset\ஏ\ஏ (12).wav
# Checking file: audio_dataset\ஏ\ஏ (13).wav
# Loading file: audio_dataset\ஏ\ஏ (13).wav
# Checking file: audio_dataset\ஏ\ஏ (14).wav
# Loading file: audio_dataset\ஏ\ஏ (14).wav
# Checking file: audio_dataset\ஏ\ஏ (15).wav
# Loading file: audio_dataset\ஏ\ஏ (15).wav
# Checking file: audio_dataset\ஏ\ஏ (16).wav
# Loading file: audio_dataset\ஏ\ஏ (16).wav
# Checking file: audio_dataset\ஏ\ஏ (17).wav
# Loading file: audio_dataset\ஏ\ஏ (17).wav
# Checking file: audio_dataset\ஏ\ஏ (18).wav
# Loading file: audio_dataset\ஏ\ஏ (18).wav
# Checking file: audio_dataset\ஏ\ஏ (19).wav
# Loading file: audio_dataset\ஏ\ஏ (19).wav
# Checking file: audio_dataset\ஏ\ஏ (2).wav
# Loading file: audio_dataset\ஏ\ஏ (2).wav
# Checking file: audio_dataset\ஏ\ஏ (20).wav
# Loading file: audio_dataset\ஏ\ஏ (20).wav
# Checking file: audio_dataset\ஏ\ஏ (21).wav
# Loading file: audio_dataset\ஏ\ஏ (21).wav
# Checking file: audio_dataset\ஏ\ஏ (22).wav
# Loading file: audio_dataset\ஏ\ஏ (22).wav
# Checking file: audio_dataset\ஏ\ஏ (23).wav
# Loading file: audio_dataset\ஏ\ஏ (23).wav
# Checking file: audio_dataset\ஏ\ஏ (24).wav
# Loading file: audio_dataset\ஏ\ஏ (24).wav
# Checking file: audio_dataset\ஏ\ஏ (25).wav
# Loading file: audio_dataset\ஏ\ஏ (25).wav
# Checking file: audio_dataset\ஏ\ஏ (26).wav
# Loading file: audio_dataset\ஏ\ஏ (26).wav
# Checking file: audio_dataset\ஏ\ஏ (27).wav
# Loading file: audio_dataset\ஏ\ஏ (27).wav
# Checking file: audio_dataset\ஏ\ஏ (28).wav
# Loading file: audio_dataset\ஏ\ஏ (28).wav
# Checking file: audio_dataset\ஏ\ஏ (29).wav
# Loading file: audio_dataset\ஏ\ஏ (29).wav
# Checking file: audio_dataset\ஏ\ஏ (3).wav
# Loading file: audio_dataset\ஏ\ஏ (3).wav
# Checking file: audio_dataset\ஏ\ஏ (30).wav
# Loading file: audio_dataset\ஏ\ஏ (30).wav
# Checking file: audio_dataset\ஏ\ஏ (31).wav
# Loading file: audio_dataset\ஏ\ஏ (31).wav
# Checking file: audio_dataset\ஏ\ஏ (32).wav
# Loading file: audio_dataset\ஏ\ஏ (32).wav
# Checking file: audio_dataset\ஏ\ஏ (33).wav
# Loading file: audio_dataset\ஏ\ஏ (33).wav
# Checking file: audio_dataset\ஏ\ஏ (34).wav
# Loading file: audio_dataset\ஏ\ஏ (34).wav
# Checking file: audio_dataset\ஏ\ஏ (35).wav
# Loading file: audio_dataset\ஏ\ஏ (35).wav
# Checking file: audio_dataset\ஏ\ஏ (36).wav
# Loading file: audio_dataset\ஏ\ஏ (36).wav
# Checking file: audio_dataset\ஏ\ஏ (37).wav
# Loading file: audio_dataset\ஏ\ஏ (37).wav
# Checking file: audio_dataset\ஏ\ஏ (38).wav
# Loading file: audio_dataset\ஏ\ஏ (38).wav
# Checking file: audio_dataset\ஏ\ஏ (39).wav
# Loading file: audio_dataset\ஏ\ஏ (39).wav
# Checking file: audio_dataset\ஏ\ஏ (4).wav
# Loading file: audio_dataset\ஏ\ஏ (4).wav
# Checking file: audio_dataset\ஏ\ஏ (40).wav
# Loading file: audio_dataset\ஏ\ஏ (40).wav
# Checking file: audio_dataset\ஏ\ஏ (41).wav
# Loading file: audio_dataset\ஏ\ஏ (41).wav
# Checking file: audio_dataset\ஏ\ஏ (42).wav
# Loading file: audio_dataset\ஏ\ஏ (42).wav
# Checking file: audio_dataset\ஏ\ஏ (43).wav
# Loading file: audio_dataset\ஏ\ஏ (43).wav
# Checking file: audio_dataset\ஏ\ஏ (44).wav
# Loading file: audio_dataset\ஏ\ஏ (44).wav
# Checking file: audio_dataset\ஏ\ஏ (45).wav
# Loading file: audio_dataset\ஏ\ஏ (45).wav
# Checking file: audio_dataset\ஏ\ஏ (46).wav
# Loading file: audio_dataset\ஏ\ஏ (46).wav
# Checking file: audio_dataset\ஏ\ஏ (47).wav
# Loading file: audio_dataset\ஏ\ஏ (47).wav
# Checking file: audio_dataset\ஏ\ஏ (48).wav
# Loading file: audio_dataset\ஏ\ஏ (48).wav
# Checking file: audio_dataset\ஏ\ஏ (49).wav
# Loading file: audio_dataset\ஏ\ஏ (49).wav
# Checking file: audio_dataset\ஏ\ஏ (5).wav
# Loading file: audio_dataset\ஏ\ஏ (5).wav
# Checking file: audio_dataset\ஏ\ஏ (50).wav
# Loading file: audio_dataset\ஏ\ஏ (50).wav
# Checking file: audio_dataset\ஏ\ஏ (6).wav
# Loading file: audio_dataset\ஏ\ஏ (6).wav
# Checking file: audio_dataset\ஏ\ஏ (7).wav
# Loading file: audio_dataset\ஏ\ஏ (7).wav
# Checking file: audio_dataset\ஏ\ஏ (8).wav
# Loading file: audio_dataset\ஏ\ஏ (8).wav
# Checking file: audio_dataset\ஏ\ஏ (9).wav
# Loading file: audio_dataset\ஏ\ஏ (9).wav
# Processing directory: audio_dataset\ஐ
# Checking file: audio_dataset\ஐ\old
# Skipped: audio_dataset\ஐ\old is not a valid .wav file.
# Checking file: audio_dataset\ஐ\ஐ (1).wav
# Loading file: audio_dataset\ஐ\ஐ (1).wav
# Checking file: audio_dataset\ஐ\ஐ (10).wav
# Loading file: audio_dataset\ஐ\ஐ (10).wav
# Checking file: audio_dataset\ஐ\ஐ (11).wav
# Loading file: audio_dataset\ஐ\ஐ (11).wav
# Checking file: audio_dataset\ஐ\ஐ (12).wav
# Loading file: audio_dataset\ஐ\ஐ (12).wav
# Checking file: audio_dataset\ஐ\ஐ (13).wav
# Loading file: audio_dataset\ஐ\ஐ (13).wav
# Checking file: audio_dataset\ஐ\ஐ (14).wav
# Loading file: audio_dataset\ஐ\ஐ (14).wav
# Checking file: audio_dataset\ஐ\ஐ (15).wav
# Loading file: audio_dataset\ஐ\ஐ (15).wav
# Checking file: audio_dataset\ஐ\ஐ (16).wav
# Loading file: audio_dataset\ஐ\ஐ (16).wav
# Checking file: audio_dataset\ஐ\ஐ (17).wav
# Loading file: audio_dataset\ஐ\ஐ (17).wav
# Checking file: audio_dataset\ஐ\ஐ (18).wav
# Loading file: audio_dataset\ஐ\ஐ (18).wav
# Checking file: audio_dataset\ஐ\ஐ (19).wav
# Loading file: audio_dataset\ஐ\ஐ (19).wav
# Checking file: audio_dataset\ஐ\ஐ (2).wav
# Loading file: audio_dataset\ஐ\ஐ (2).wav
# Checking file: audio_dataset\ஐ\ஐ (20).wav
# Loading file: audio_dataset\ஐ\ஐ (20).wav
# Checking file: audio_dataset\ஐ\ஐ (21).wav
# Loading file: audio_dataset\ஐ\ஐ (21).wav
# Checking file: audio_dataset\ஐ\ஐ (22).wav
# Loading file: audio_dataset\ஐ\ஐ (22).wav
# Checking file: audio_dataset\ஐ\ஐ (23).wav
# Loading file: audio_dataset\ஐ\ஐ (23).wav
# Checking file: audio_dataset\ஐ\ஐ (24).wav
# Loading file: audio_dataset\ஐ\ஐ (24).wav
# Checking file: audio_dataset\ஐ\ஐ (25).wav
# Loading file: audio_dataset\ஐ\ஐ (25).wav
# Checking file: audio_dataset\ஐ\ஐ (26).wav
# Loading file: audio_dataset\ஐ\ஐ (26).wav
# Checking file: audio_dataset\ஐ\ஐ (27).wav
# Loading file: audio_dataset\ஐ\ஐ (27).wav
# Checking file: audio_dataset\ஐ\ஐ (28).wav
# Loading file: audio_dataset\ஐ\ஐ (28).wav
# Checking file: audio_dataset\ஐ\ஐ (29).wav
# Loading file: audio_dataset\ஐ\ஐ (29).wav
# Checking file: audio_dataset\ஐ\ஐ (3).wav
# Loading file: audio_dataset\ஐ\ஐ (3).wav
# Checking file: audio_dataset\ஐ\ஐ (30).wav
# Loading file: audio_dataset\ஐ\ஐ (30).wav
# Checking file: audio_dataset\ஐ\ஐ (31).wav
# Loading file: audio_dataset\ஐ\ஐ (31).wav
# Checking file: audio_dataset\ஐ\ஐ (32).wav
# Loading file: audio_dataset\ஐ\ஐ (32).wav
# Checking file: audio_dataset\ஐ\ஐ (33).wav
# Loading file: audio_dataset\ஐ\ஐ (33).wav
# Checking file: audio_dataset\ஐ\ஐ (34).wav
# Loading file: audio_dataset\ஐ\ஐ (34).wav
# Checking file: audio_dataset\ஐ\ஐ (35).wav
# Loading file: audio_dataset\ஐ\ஐ (35).wav
# Checking file: audio_dataset\ஐ\ஐ (36).wav
# Loading file: audio_dataset\ஐ\ஐ (36).wav
# Checking file: audio_dataset\ஐ\ஐ (37).wav
# Loading file: audio_dataset\ஐ\ஐ (37).wav
# Checking file: audio_dataset\ஐ\ஐ (38).wav
# Loading file: audio_dataset\ஐ\ஐ (38).wav
# Checking file: audio_dataset\ஐ\ஐ (39).wav
# Loading file: audio_dataset\ஐ\ஐ (39).wav
# Checking file: audio_dataset\ஐ\ஐ (4).wav
# Loading file: audio_dataset\ஐ\ஐ (4).wav
# Checking file: audio_dataset\ஐ\ஐ (40).wav
# Loading file: audio_dataset\ஐ\ஐ (40).wav
# Checking file: audio_dataset\ஐ\ஐ (41).wav
# Loading file: audio_dataset\ஐ\ஐ (41).wav
# Checking file: audio_dataset\ஐ\ஐ (42).wav
# Loading file: audio_dataset\ஐ\ஐ (42).wav
# Checking file: audio_dataset\ஐ\ஐ (43).wav
# Loading file: audio_dataset\ஐ\ஐ (43).wav
# Checking file: audio_dataset\ஐ\ஐ (44).wav
# Loading file: audio_dataset\ஐ\ஐ (44).wav
# Checking file: audio_dataset\ஐ\ஐ (45).wav
# Loading file: audio_dataset\ஐ\ஐ (45).wav
# Checking file: audio_dataset\ஐ\ஐ (46).wav
# Loading file: audio_dataset\ஐ\ஐ (46).wav
# Checking file: audio_dataset\ஐ\ஐ (47).wav
# Loading file: audio_dataset\ஐ\ஐ (47).wav
# Checking file: audio_dataset\ஐ\ஐ (48).wav
# Loading file: audio_dataset\ஐ\ஐ (48).wav
# Checking file: audio_dataset\ஐ\ஐ (49).wav
# Loading file: audio_dataset\ஐ\ஐ (49).wav
# Checking file: audio_dataset\ஐ\ஐ (5).wav
# Loading file: audio_dataset\ஐ\ஐ (5).wav
# Checking file: audio_dataset\ஐ\ஐ (50).wav
# Loading file: audio_dataset\ஐ\ஐ (50).wav
# Checking file: audio_dataset\ஐ\ஐ (51).wav
# Loading file: audio_dataset\ஐ\ஐ (51).wav
# Checking file: audio_dataset\ஐ\ஐ (6).wav
# Loading file: audio_dataset\ஐ\ஐ (6).wav
# Checking file: audio_dataset\ஐ\ஐ (7).wav
# Loading file: audio_dataset\ஐ\ஐ (7).wav
# Checking file: audio_dataset\ஐ\ஐ (8).wav
# Loading file: audio_dataset\ஐ\ஐ (8).wav
# Checking file: audio_dataset\ஐ\ஐ (9).wav
# Loading file: audio_dataset\ஐ\ஐ (9).wav
# Processing directory: audio_dataset\ஒ
# Checking file: audio_dataset\ஒ\old
# Skipped: audio_dataset\ஒ\old is not a valid .wav file.
# Checking file: audio_dataset\ஒ\ஒ (1).wav
# Loading file: audio_dataset\ஒ\ஒ (1).wav
# Checking file: audio_dataset\ஒ\ஒ (10).wav
# Loading file: audio_dataset\ஒ\ஒ (10).wav
# Checking file: audio_dataset\ஒ\ஒ (11).wav
# Loading file: audio_dataset\ஒ\ஒ (11).wav
# Checking file: audio_dataset\ஒ\ஒ (12).wav
# Loading file: audio_dataset\ஒ\ஒ (12).wav
# Checking file: audio_dataset\ஒ\ஒ (13).wav
# Loading file: audio_dataset\ஒ\ஒ (13).wav
# Checking file: audio_dataset\ஒ\ஒ (14).wav
# Loading file: audio_dataset\ஒ\ஒ (14).wav
# Checking file: audio_dataset\ஒ\ஒ (15).wav
# Loading file: audio_dataset\ஒ\ஒ (15).wav
# Checking file: audio_dataset\ஒ\ஒ (16).wav
# Loading file: audio_dataset\ஒ\ஒ (16).wav
# Checking file: audio_dataset\ஒ\ஒ (17).wav
# Loading file: audio_dataset\ஒ\ஒ (17).wav
# Checking file: audio_dataset\ஒ\ஒ (18).wav
# Loading file: audio_dataset\ஒ\ஒ (18).wav
# Checking file: audio_dataset\ஒ\ஒ (19).wav
# Loading file: audio_dataset\ஒ\ஒ (19).wav
# Checking file: audio_dataset\ஒ\ஒ (2).wav
# Loading file: audio_dataset\ஒ\ஒ (2).wav
# Checking file: audio_dataset\ஒ\ஒ (20).wav
# Loading file: audio_dataset\ஒ\ஒ (20).wav
# Checking file: audio_dataset\ஒ\ஒ (21).wav
# Loading file: audio_dataset\ஒ\ஒ (21).wav
# Checking file: audio_dataset\ஒ\ஒ (22).wav
# Loading file: audio_dataset\ஒ\ஒ (22).wav
# Checking file: audio_dataset\ஒ\ஒ (23).wav
# Loading file: audio_dataset\ஒ\ஒ (23).wav
# Checking file: audio_dataset\ஒ\ஒ (24).wav
# Loading file: audio_dataset\ஒ\ஒ (24).wav
# Checking file: audio_dataset\ஒ\ஒ (25).wav
# Loading file: audio_dataset\ஒ\ஒ (25).wav
# Checking file: audio_dataset\ஒ\ஒ (26).wav
# Loading file: audio_dataset\ஒ\ஒ (26).wav
# Checking file: audio_dataset\ஒ\ஒ (27).wav
# Loading file: audio_dataset\ஒ\ஒ (27).wav
# Checking file: audio_dataset\ஒ\ஒ (28).wav
# Loading file: audio_dataset\ஒ\ஒ (28).wav
# Checking file: audio_dataset\ஒ\ஒ (29).wav
# Loading file: audio_dataset\ஒ\ஒ (29).wav
# Checking file: audio_dataset\ஒ\ஒ (3).wav
# Loading file: audio_dataset\ஒ\ஒ (3).wav
# Checking file: audio_dataset\ஒ\ஒ (30).wav
# Loading file: audio_dataset\ஒ\ஒ (30).wav
# Checking file: audio_dataset\ஒ\ஒ (31).wav
# Loading file: audio_dataset\ஒ\ஒ (31).wav
# Checking file: audio_dataset\ஒ\ஒ (32).wav
# Loading file: audio_dataset\ஒ\ஒ (32).wav
# Checking file: audio_dataset\ஒ\ஒ (33).wav
# Loading file: audio_dataset\ஒ\ஒ (33).wav
# Checking file: audio_dataset\ஒ\ஒ (34).wav
# Loading file: audio_dataset\ஒ\ஒ (34).wav
# Checking file: audio_dataset\ஒ\ஒ (35).wav
# Loading file: audio_dataset\ஒ\ஒ (35).wav
# Checking file: audio_dataset\ஒ\ஒ (36).wav
# Loading file: audio_dataset\ஒ\ஒ (36).wav
# Checking file: audio_dataset\ஒ\ஒ (37).wav
# Loading file: audio_dataset\ஒ\ஒ (37).wav
# Checking file: audio_dataset\ஒ\ஒ (38).wav
# Loading file: audio_dataset\ஒ\ஒ (38).wav
# Checking file: audio_dataset\ஒ\ஒ (39).wav
# Loading file: audio_dataset\ஒ\ஒ (39).wav
# Checking file: audio_dataset\ஒ\ஒ (4).wav
# Loading file: audio_dataset\ஒ\ஒ (4).wav
# Checking file: audio_dataset\ஒ\ஒ (40).wav
# Loading file: audio_dataset\ஒ\ஒ (40).wav
# Checking file: audio_dataset\ஒ\ஒ (41).wav
# Loading file: audio_dataset\ஒ\ஒ (41).wav
# Checking file: audio_dataset\ஒ\ஒ (42).wav
# Loading file: audio_dataset\ஒ\ஒ (42).wav
# Checking file: audio_dataset\ஒ\ஒ (43).wav
# Loading file: audio_dataset\ஒ\ஒ (43).wav
# Checking file: audio_dataset\ஒ\ஒ (44).wav
# Loading file: audio_dataset\ஒ\ஒ (44).wav
# Checking file: audio_dataset\ஒ\ஒ (45).wav
# Loading file: audio_dataset\ஒ\ஒ (45).wav
# Checking file: audio_dataset\ஒ\ஒ (46).wav
# Loading file: audio_dataset\ஒ\ஒ (46).wav
# Checking file: audio_dataset\ஒ\ஒ (47).wav
# Loading file: audio_dataset\ஒ\ஒ (47).wav
# Checking file: audio_dataset\ஒ\ஒ (48).wav
# Loading file: audio_dataset\ஒ\ஒ (48).wav
# Checking file: audio_dataset\ஒ\ஒ (49).wav
# Loading file: audio_dataset\ஒ\ஒ (49).wav
# Checking file: audio_dataset\ஒ\ஒ (5).wav
# Loading file: audio_dataset\ஒ\ஒ (5).wav
# Checking file: audio_dataset\ஒ\ஒ (50).wav
# Loading file: audio_dataset\ஒ\ஒ (50).wav
# Checking file: audio_dataset\ஒ\ஒ (6).wav
# Loading file: audio_dataset\ஒ\ஒ (6).wav
# Checking file: audio_dataset\ஒ\ஒ (7).wav
# Loading file: audio_dataset\ஒ\ஒ (7).wav
# Checking file: audio_dataset\ஒ\ஒ (8).wav
# Loading file: audio_dataset\ஒ\ஒ (8).wav
# Checking file: audio_dataset\ஒ\ஒ (9).wav
# Loading file: audio_dataset\ஒ\ஒ (9).wav
# Processing directory: audio_dataset\ஓ
# Checking file: audio_dataset\ஓ\old
# Skipped: audio_dataset\ஓ\old is not a valid .wav file.
# Checking file: audio_dataset\ஓ\ஓ (1).wav
# Loading file: audio_dataset\ஓ\ஓ (1).wav
# Checking file: audio_dataset\ஓ\ஓ (10).wav
# Loading file: audio_dataset\ஓ\ஓ (10).wav
# Checking file: audio_dataset\ஓ\ஓ (11).wav
# Loading file: audio_dataset\ஓ\ஓ (11).wav
# Checking file: audio_dataset\ஓ\ஓ (12).wav
# Loading file: audio_dataset\ஓ\ஓ (12).wav
# Checking file: audio_dataset\ஓ\ஓ (13).wav
# Loading file: audio_dataset\ஓ\ஓ (13).wav
# Checking file: audio_dataset\ஓ\ஓ (14).wav
# Loading file: audio_dataset\ஓ\ஓ (14).wav
# Checking file: audio_dataset\ஓ\ஓ (15).wav
# Loading file: audio_dataset\ஓ\ஓ (15).wav
# Checking file: audio_dataset\ஓ\ஓ (16).wav
# Loading file: audio_dataset\ஓ\ஓ (16).wav
# Checking file: audio_dataset\ஓ\ஓ (17).wav
# Loading file: audio_dataset\ஓ\ஓ (17).wav
# Checking file: audio_dataset\ஓ\ஓ (18).wav
# Loading file: audio_dataset\ஓ\ஓ (18).wav
# Checking file: audio_dataset\ஓ\ஓ (19).wav
# Loading file: audio_dataset\ஓ\ஓ (19).wav
# Checking file: audio_dataset\ஓ\ஓ (2).wav
# Loading file: audio_dataset\ஓ\ஓ (2).wav
# Checking file: audio_dataset\ஓ\ஓ (20).wav
# Loading file: audio_dataset\ஓ\ஓ (20).wav
# Checking file: audio_dataset\ஓ\ஓ (21).wav
# Loading file: audio_dataset\ஓ\ஓ (21).wav
# Checking file: audio_dataset\ஓ\ஓ (22).wav
# Loading file: audio_dataset\ஓ\ஓ (22).wav
# Checking file: audio_dataset\ஓ\ஓ (23).wav
# Loading file: audio_dataset\ஓ\ஓ (23).wav
# Checking file: audio_dataset\ஓ\ஓ (24).wav
# Loading file: audio_dataset\ஓ\ஓ (24).wav
# Checking file: audio_dataset\ஓ\ஓ (25).wav
# Loading file: audio_dataset\ஓ\ஓ (25).wav
# Checking file: audio_dataset\ஓ\ஓ (26).wav
# Loading file: audio_dataset\ஓ\ஓ (26).wav
# Checking file: audio_dataset\ஓ\ஓ (27).wav
# Loading file: audio_dataset\ஓ\ஓ (27).wav
# Checking file: audio_dataset\ஓ\ஓ (28).wav
# Loading file: audio_dataset\ஓ\ஓ (28).wav
# Checking file: audio_dataset\ஓ\ஓ (29).wav
# Loading file: audio_dataset\ஓ\ஓ (29).wav
# Checking file: audio_dataset\ஓ\ஓ (3).wav
# Loading file: audio_dataset\ஓ\ஓ (3).wav
# Checking file: audio_dataset\ஓ\ஓ (30).wav
# Loading file: audio_dataset\ஓ\ஓ (30).wav
# Checking file: audio_dataset\ஓ\ஓ (31).wav
# Loading file: audio_dataset\ஓ\ஓ (31).wav
# Checking file: audio_dataset\ஓ\ஓ (32).wav
# Loading file: audio_dataset\ஓ\ஓ (32).wav
# Checking file: audio_dataset\ஓ\ஓ (33).wav
# Loading file: audio_dataset\ஓ\ஓ (33).wav
# Checking file: audio_dataset\ஓ\ஓ (34).wav
# Loading file: audio_dataset\ஓ\ஓ (34).wav
# Checking file: audio_dataset\ஓ\ஓ (35).wav
# Loading file: audio_dataset\ஓ\ஓ (35).wav
# Checking file: audio_dataset\ஓ\ஓ (36).wav
# Loading file: audio_dataset\ஓ\ஓ (36).wav
# Checking file: audio_dataset\ஓ\ஓ (37).wav
# Loading file: audio_dataset\ஓ\ஓ (37).wav
# Checking file: audio_dataset\ஓ\ஓ (38).wav
# Loading file: audio_dataset\ஓ\ஓ (38).wav
# Checking file: audio_dataset\ஓ\ஓ (39).wav
# Loading file: audio_dataset\ஓ\ஓ (39).wav
# Checking file: audio_dataset\ஓ\ஓ (4).wav
# Loading file: audio_dataset\ஓ\ஓ (4).wav
# Checking file: audio_dataset\ஓ\ஓ (40).wav
# Loading file: audio_dataset\ஓ\ஓ (40).wav
# Checking file: audio_dataset\ஓ\ஓ (41).wav
# Loading file: audio_dataset\ஓ\ஓ (41).wav
# Checking file: audio_dataset\ஓ\ஓ (42).wav
# Loading file: audio_dataset\ஓ\ஓ (42).wav
# Checking file: audio_dataset\ஓ\ஓ (43).wav
# Loading file: audio_dataset\ஓ\ஓ (43).wav
# Checking file: audio_dataset\ஓ\ஓ (44).wav
# Loading file: audio_dataset\ஓ\ஓ (44).wav
# Checking file: audio_dataset\ஓ\ஓ (45).wav
# Loading file: audio_dataset\ஓ\ஓ (45).wav
# Checking file: audio_dataset\ஓ\ஓ (46).wav
# Loading file: audio_dataset\ஓ\ஓ (46).wav
# Checking file: audio_dataset\ஓ\ஓ (47).wav
# Loading file: audio_dataset\ஓ\ஓ (47).wav
# Checking file: audio_dataset\ஓ\ஓ (48).wav
# Loading file: audio_dataset\ஓ\ஓ (48).wav
# Checking file: audio_dataset\ஓ\ஓ (49).wav
# Loading file: audio_dataset\ஓ\ஓ (49).wav
# Checking file: audio_dataset\ஓ\ஓ (5).wav
# Loading file: audio_dataset\ஓ\ஓ (5).wav
# Checking file: audio_dataset\ஓ\ஓ (50).wav
# Loading file: audio_dataset\ஓ\ஓ (50).wav
# Checking file: audio_dataset\ஓ\ஓ (6).wav
# Loading file: audio_dataset\ஓ\ஓ (6).wav
# Checking file: audio_dataset\ஓ\ஓ (7).wav
# Loading file: audio_dataset\ஓ\ஓ (7).wav
# Checking file: audio_dataset\ஓ\ஓ (8).wav
# Loading file: audio_dataset\ஓ\ஓ (8).wav
# Checking file: audio_dataset\ஓ\ஓ (9).wav
# Loading file: audio_dataset\ஓ\ஓ (9).wav
# Processing directory: audio_dataset\ஔ
# Checking file: audio_dataset\ஔ\old
# Skipped: audio_dataset\ஔ\old is not a valid .wav file.
# Checking file: audio_dataset\ஔ\ஔ (1).wav
# Loading file: audio_dataset\ஔ\ஔ (1).wav
# Checking file: audio_dataset\ஔ\ஔ (10).wav
# Loading file: audio_dataset\ஔ\ஔ (10).wav
# Checking file: audio_dataset\ஔ\ஔ (11).wav
# Loading file: audio_dataset\ஔ\ஔ (11).wav
# Checking file: audio_dataset\ஔ\ஔ (12).wav
# Loading file: audio_dataset\ஔ\ஔ (12).wav
# Checking file: audio_dataset\ஔ\ஔ (13).wav
# Loading file: audio_dataset\ஔ\ஔ (13).wav
# Checking file: audio_dataset\ஔ\ஔ (14).wav
# Loading file: audio_dataset\ஔ\ஔ (14).wav
# Checking file: audio_dataset\ஔ\ஔ (15).wav
# Loading file: audio_dataset\ஔ\ஔ (15).wav
# Checking file: audio_dataset\ஔ\ஔ (16).wav
# Loading file: audio_dataset\ஔ\ஔ (16).wav
# Checking file: audio_dataset\ஔ\ஔ (17).wav
# Loading file: audio_dataset\ஔ\ஔ (17).wav
# Checking file: audio_dataset\ஔ\ஔ (18).wav
# Loading file: audio_dataset\ஔ\ஔ (18).wav
# Checking file: audio_dataset\ஔ\ஔ (19).wav
# Loading file: audio_dataset\ஔ\ஔ (19).wav
# Checking file: audio_dataset\ஔ\ஔ (2).wav
# Loading file: audio_dataset\ஔ\ஔ (2).wav
# Checking file: audio_dataset\ஔ\ஔ (20).wav
# Loading file: audio_dataset\ஔ\ஔ (20).wav
# Checking file: audio_dataset\ஔ\ஔ (21).wav
# Loading file: audio_dataset\ஔ\ஔ (21).wav
# Checking file: audio_dataset\ஔ\ஔ (22).wav
# Loading file: audio_dataset\ஔ\ஔ (22).wav
# Checking file: audio_dataset\ஔ\ஔ (23).wav
# Loading file: audio_dataset\ஔ\ஔ (23).wav
# Checking file: audio_dataset\ஔ\ஔ (24).wav
# Loading file: audio_dataset\ஔ\ஔ (24).wav
# Checking file: audio_dataset\ஔ\ஔ (25).wav
# Loading file: audio_dataset\ஔ\ஔ (25).wav
# Checking file: audio_dataset\ஔ\ஔ (26).wav
# Loading file: audio_dataset\ஔ\ஔ (26).wav
# Checking file: audio_dataset\ஔ\ஔ (27).wav
# Loading file: audio_dataset\ஔ\ஔ (27).wav
# Checking file: audio_dataset\ஔ\ஔ (28).wav
# Loading file: audio_dataset\ஔ\ஔ (28).wav
# Checking file: audio_dataset\ஔ\ஔ (29).wav
# Loading file: audio_dataset\ஔ\ஔ (29).wav
# Checking file: audio_dataset\ஔ\ஔ (3).wav
# Loading file: audio_dataset\ஔ\ஔ (3).wav
# Checking file: audio_dataset\ஔ\ஔ (30).wav
# Loading file: audio_dataset\ஔ\ஔ (30).wav
# Checking file: audio_dataset\ஔ\ஔ (31).wav
# Loading file: audio_dataset\ஔ\ஔ (31).wav
# Checking file: audio_dataset\ஔ\ஔ (32).wav
# Loading file: audio_dataset\ஔ\ஔ (32).wav
# Checking file: audio_dataset\ஔ\ஔ (33).wav
# Loading file: audio_dataset\ஔ\ஔ (33).wav
# Checking file: audio_dataset\ஔ\ஔ (34).wav
# Loading file: audio_dataset\ஔ\ஔ (34).wav
# Checking file: audio_dataset\ஔ\ஔ (35).wav
# Loading file: audio_dataset\ஔ\ஔ (35).wav
# Checking file: audio_dataset\ஔ\ஔ (36).wav
# Loading file: audio_dataset\ஔ\ஔ (36).wav
# Checking file: audio_dataset\ஔ\ஔ (37).wav
# Loading file: audio_dataset\ஔ\ஔ (37).wav
# Checking file: audio_dataset\ஔ\ஔ (38).wav
# Loading file: audio_dataset\ஔ\ஔ (38).wav
# Checking file: audio_dataset\ஔ\ஔ (39).wav
# Loading file: audio_dataset\ஔ\ஔ (39).wav
# Checking file: audio_dataset\ஔ\ஔ (4).wav
# Loading file: audio_dataset\ஔ\ஔ (4).wav
# Checking file: audio_dataset\ஔ\ஔ (40).wav
# Loading file: audio_dataset\ஔ\ஔ (40).wav
# Checking file: audio_dataset\ஔ\ஔ (41).wav
# Loading file: audio_dataset\ஔ\ஔ (41).wav
# Checking file: audio_dataset\ஔ\ஔ (42).wav
# Loading file: audio_dataset\ஔ\ஔ (42).wav
# Checking file: audio_dataset\ஔ\ஔ (43).wav
# Loading file: audio_dataset\ஔ\ஔ (43).wav
# Checking file: audio_dataset\ஔ\ஔ (44).wav
# Loading file: audio_dataset\ஔ\ஔ (44).wav
# Checking file: audio_dataset\ஔ\ஔ (45).wav
# Loading file: audio_dataset\ஔ\ஔ (45).wav
# Checking file: audio_dataset\ஔ\ஔ (46).wav
# Loading file: audio_dataset\ஔ\ஔ (46).wav
# Checking file: audio_dataset\ஔ\ஔ (47).wav
# Loading file: audio_dataset\ஔ\ஔ (47).wav
# Checking file: audio_dataset\ஔ\ஔ (48).wav
# Loading file: audio_dataset\ஔ\ஔ (48).wav
# Checking file: audio_dataset\ஔ\ஔ (49).wav
# Loading file: audio_dataset\ஔ\ஔ (49).wav
# Checking file: audio_dataset\ஔ\ஔ (5).wav
# Loading file: audio_dataset\ஔ\ஔ (5).wav
# Checking file: audio_dataset\ஔ\ஔ (50).wav
# Loading file: audio_dataset\ஔ\ஔ (50).wav
# Checking file: audio_dataset\ஔ\ஔ (6).wav
# Loading file: audio_dataset\ஔ\ஔ (6).wav
# Checking file: audio_dataset\ஔ\ஔ (7).wav
# Loading file: audio_dataset\ஔ\ஔ (7).wav
# Checking file: audio_dataset\ஔ\ஔ (8).wav
# Loading file: audio_dataset\ஔ\ஔ (8).wav
# Checking file: audio_dataset\ஔ\ஔ (9).wav
# Loading file: audio_dataset\ஔ\ஔ (9).wav
# Loaded 601 audio files.
# Extracted MFCC features from 601 audio files.
# C:\Users\Shyamsundhar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.1801 - loss: 2.8920 - val_accuracy: 0.0744 - val_loss: 30.8715 - learning_rate: 0.0010
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2905 - loss: 2.1007 - val_accuracy: 0.0744 - val_loss: 40.8081 - learning_rate: 0.0010
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3831 - loss: 2.0127 - val_accuracy: 0.0744 - val_loss: 40.8659 - learning_rate: 0.0010
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4212 - loss: 1.7504 - val_accuracy: 0.0744 - val_loss: 44.0222 - learning_rate: 0.0010
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4777 - loss: 1.6220 - val_accuracy: 0.0744 - val_loss: 44.1455 - learning_rate: 2.0000e-04
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4543 - loss: 1.5369 - val_accuracy: 0.0744 - val_loss: 42.9359 - learning_rate: 2.0000e-04
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4374 - loss: 1.6648 - val_accuracy: 0.0744 - val_loss: 41.0473 - learning_rate: 2.0000e-04
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4401 - loss: 1.5867 - val_accuracy: 0.0744 - val_loss: 38.0433 - learning_rate: 4.0000e-05
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4518 - loss: 1.6080 - val_accuracy: 0.0744 - val_loss: 35.0950 - learning_rate: 4.0000e-05
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4711 - loss: 1.5905 - val_accuracy: 0.0744 - val_loss: 32.6121 - learning_rate: 4.0000e-05
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5251 - loss: 1.4329 - val_accuracy: 0.0744 - val_loss: 29.8159 - learning_rate: 1.0000e-05
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5124 - loss: 1.4963 - val_accuracy: 0.0744 - val_loss: 27.0631 - learning_rate: 1.0000e-05
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4884 - loss: 1.5250 - val_accuracy: 0.0744 - val_loss: 24.5247 - learning_rate: 1.0000e-05
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4847 - loss: 1.5391 - val_accuracy: 0.0744 - val_loss: 22.1741 - learning_rate: 1.0000e-05
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4844 - loss: 1.4515 - val_accuracy: 0.0744 - val_loss: 20.1206 - learning_rate: 1.0000e-05
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4909 - loss: 1.4999 - val_accuracy: 0.0744 - val_loss: 18.0479 - learning_rate: 1.0000e-05
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4346 - loss: 1.5899 - val_accuracy: 0.0744 - val_loss: 16.0700 - learning_rate: 1.0000e-05
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4402 - loss: 1.5666 - val_accuracy: 0.0744 - val_loss: 14.4660 - learning_rate: 1.0000e-05
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5233 - loss: 1.4739 - val_accuracy: 0.0744 - val_loss: 12.8080 - learning_rate: 1.0000e-05
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5189 - loss: 1.4839 - val_accuracy: 0.0744 - val_loss: 11.4111 - learning_rate: 1.0000e-05
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4718 - loss: 1.5668 - val_accuracy: 0.0744 - val_loss: 10.1976 - learning_rate: 1.0000e-05
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4615 - loss: 1.5781 - val_accuracy: 0.0744 - val_loss: 9.0757 - learning_rate: 1.0000e-05
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4855 - loss: 1.5169 - val_accuracy: 0.0744 - val_loss: 8.0237 - learning_rate: 1.0000e-05
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5057 - loss: 1.4204 - val_accuracy: 0.0744 - val_loss: 7.0454 - learning_rate: 1.0000e-05
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5408 - loss: 1.3847 - val_accuracy: 0.0909 - val_loss: 6.2096 - learning_rate: 1.0000e-05
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4498 - loss: 1.5600 - val_accuracy: 0.0909 - val_loss: 5.4479 - learning_rate: 1.0000e-05
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4920 - loss: 1.5756 - val_accuracy: 0.0992 - val_loss: 4.7628 - learning_rate: 1.0000e-05
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4821 - loss: 1.5175 - val_accuracy: 0.1074 - val_loss: 4.1919 - learning_rate: 1.0000e-05
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4549 - loss: 1.6095 - val_accuracy: 0.1240 - val_loss: 3.7043 - learning_rate: 1.0000e-05
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5140 - loss: 1.4026 - val_accuracy: 0.1736 - val_loss: 3.2915 - learning_rate: 1.0000e-05
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4796 - loss: 1.4970 - val_accuracy: 0.2066 - val_loss: 2.9447 - learning_rate: 1.0000e-05
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4961 - loss: 1.4097 - val_accuracy: 0.2066 - val_loss: 2.6739 - learning_rate: 1.0000e-05
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4939 - loss: 1.4602 - val_accuracy: 0.2314 - val_loss: 2.4226 - learning_rate: 1.0000e-05
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5037 - loss: 1.3984 - val_accuracy: 0.2479 - val_loss: 2.2527 - learning_rate: 1.0000e-05
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5098 - loss: 1.4264 - val_accuracy: 0.2727 - val_loss: 2.0945 - learning_rate: 1.0000e-05
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5249 - loss: 1.4254 - val_accuracy: 0.2975 - val_loss: 1.9528 - learning_rate: 1.0000e-05
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5356 - loss: 1.4066 - val_accuracy: 0.3388 - val_loss: 1.8035 - learning_rate: 1.0000e-05
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4667 - loss: 1.5570 - val_accuracy: 0.4050 - val_loss: 1.6622 - learning_rate: 1.0000e-05
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4736 - loss: 1.5817 - val_accuracy: 0.4380 - val_loss: 1.5827 - learning_rate: 1.0000e-05
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4414 - loss: 1.5749 - val_accuracy: 0.4545 - val_loss: 1.5541 - learning_rate: 1.0000e-05
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4868 - loss: 1.4837 - val_accuracy: 0.4628 - val_loss: 1.4652 - learning_rate: 1.0000e-05
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5132 - loss: 1.4677 - val_accuracy: 0.4876 - val_loss: 1.4126 - learning_rate: 1.0000e-05
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4337 - loss: 1.5277 - val_accuracy: 0.4959 - val_loss: 1.3520 - learning_rate: 1.0000e-05
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4983 - loss: 1.5126 - val_accuracy: 0.5455 - val_loss: 1.2970 - learning_rate: 1.0000e-05
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4674 - loss: 1.5149 - val_accuracy: 0.5868 - val_loss: 1.2649 - learning_rate: 1.0000e-05
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5130 - loss: 1.5373 - val_accuracy: 0.5702 - val_loss: 1.2659 - learning_rate: 1.0000e-05
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5258 - loss: 1.4285 - val_accuracy: 0.5702 - val_loss: 1.2457 - learning_rate: 1.0000e-05
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4910 - loss: 1.4535 - val_accuracy: 0.5702 - val_loss: 1.2460 - learning_rate: 1.0000e-05
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5353 - loss: 1.4223 - val_accuracy: 0.5702 - val_loss: 1.2493 - learning_rate: 1.0000e-05
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5077 - loss: 1.4587 - val_accuracy: 0.5620 - val_loss: 1.2787 - learning_rate: 1.0000e-05
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5425 - loss: 1.2821
# Test Accuracy: 56.20%
# Recording...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Recognized Tamil Uyir Letter: ஏ
# Letter: அ - Confidence: 0.00%
# Letter: ஆ - Confidence: 0.00%
# Letter: இ - Confidence: 0.00%
# Letter: ஈ - Confidence: 0.00%
# Letter: உ - Confidence: 0.00%
# Letter: ஊ - Confidence: 0.00%
# Letter: எ - Confidence: 0.00%
# Letter: ஏ - Confidence: 100.00%
# Letter: ஐ - Confidence: 0.00%
# Letter: ஒ - Confidence: 0.00%
# Letter: ஓ - Confidence: 0.00%
# Letter: ஔ - Confidence: 0.00%

# %%
# !pip install numpy pandas librosa scikit-learn tensorflow sounddevice matplotlib
import os
import numpy as np
import librosa

# Configuration
SAMPLE_RATE = 16000
N_FFT = 256  # Reduced n_fft size to handle shorter signals better
DATASET_PATH = "audio_dataset"  # Root folder containing subdirectories for each letter

def load_audio_files(dataset_path):
    
    x_data = []
    y_data = []

    # List all subdirectories in the dataset path (each representing a Tamil letter)
    labels = [d for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))]
    print(f"Detected labels (directories): {labels}")  # Debug: List detected directories

    for label in labels:
        class_path = os.path.join(dataset_path, label)  # e.g., "audio_dataset/அ"
        print(f"Processing directory: {class_path}")  # Debug: Print each directory being processed
        
        # Iterate through each audio file in the class directory
        for file_name in os.listdir(class_path):
            file_path = os.path.join(class_path, file_name)
            print(f"Checking file: {file_path}")  # Debug: Print each file path being checked
            
            # Ensure the path is a file and ends with .wav
            if os.path.isfile(file_path) and file_path.endswith('.wav'):
                print(f"Loading file: {file_path}")  # Debug: Confirm file is being loaded
                
                # Load the audio file
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
                
                # If the signal is too short, pad it with zeros
                if len(signal) < N_FFT:
                    padding = N_FFT - len(signal)
                    signal = np.pad(signal, (0, padding), 'constant')
                
                # Extract MFCC features with a reduced n_fft size
                mfccs = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=N_FFT)
                mfccs_mean = np.mean(mfccs.T, axis=0)  # Averaging MFCCs

                x_data.append(mfccs_mean)
                y_data.append(label)  # Append the label (e.g., 'அ')
            else:
                print(f"Skipped: {file_path} is not a valid .wav file.")  # Debug: Skip message for invalid files
    
    return np.array(x_data), np.array(y_data)

# Load the data
x_data, y_data = load_audio_files(DATASET_PATH)
print(f"Loaded {len(x_data)} audio files.")
# Function to extract MFCC features from audio signals
def extract_mfcc(signal, sample_rate, n_mfcc=13):
    mfccs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_mfcc=n_mfcc)
    mfccs = np.mean(mfccs.T, axis=0)  # Flatten MFCC matrix to a single vector
    return mfccs

# Extract MFCC features for each signal in the dataset
x_features = np.array([extract_mfcc(signal, SAMPLE_RATE) for signal in x_data])
print(f"Extracted MFCC features from {len(x_features)} audio files.")
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical

# Encode the class labels into numeric form
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_data)
y_categorical = to_categorical(y_encoded)

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x_features, y_categorical, test_size=0.2, random_state=42)

# Build a simple neural network model
model = Sequential([
    Dense(256, input_shape=(x_train.shape[1],), activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer with softmax activation
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32)

# Save the trained model
model.save('tamil_uyir_recognition_model.keras')
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Requirement already satisfied: numpy in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)
# Requirement already satisfied: librosa in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.10.2.post1)
# Requirement already satisfied: scikit-learn in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.5.1)
# Requirement already satisfied: tensorflow in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.17.0)
# Requirement already satisfied: sounddevice in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.0)
# Requirement already satisfied: matplotlib in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.1.post1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.14.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (4.8.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from librosa) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.25.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\program files\windowsapps\pythonsoftwarefoundation.python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: pycparser in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from CFFI>=1.0->sounddevice) (2.22)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow) (2023.7.22)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\shyamsundhar\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Detected labels (directories): ['அ', 'ஆ', 'இ', 'ஈ', 'உ', 'ஊ', 'எ', 'ஏ', 'ஐ', 'ஒ', 'ஓ', 'ஔ']
# Processing directory: audio_dataset\அ
# Checking file: audio_dataset\அ\old
# Skipped: audio_dataset\அ\old is not a valid .wav file.
# Checking file: audio_dataset\அ\அ (1).wav
# Loading file: audio_dataset\அ\அ (1).wav
# C:\Users\Shyamsundhar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# Checking file: audio_dataset\அ\அ (10).wav
# Loading file: audio_dataset\அ\அ (10).wav
# Checking file: audio_dataset\அ\அ (11).wav
# Loading file: audio_dataset\அ\அ (11).wav
# Checking file: audio_dataset\அ\அ (12).wav
# Loading file: audio_dataset\அ\அ (12).wav
# Checking file: audio_dataset\அ\அ (13).wav
# Loading file: audio_dataset\அ\அ (13).wav
# Checking file: audio_dataset\அ\அ (14).wav
# Loading file: audio_dataset\அ\அ (14).wav
# Checking file: audio_dataset\அ\அ (15).wav
# Loading file: audio_dataset\அ\அ (15).wav
# Checking file: audio_dataset\அ\அ (16).wav
# Loading file: audio_dataset\அ\அ (16).wav
# Checking file: audio_dataset\அ\அ (17).wav
# Loading file: audio_dataset\அ\அ (17).wav
# Checking file: audio_dataset\அ\அ (18).wav
# Loading file: audio_dataset\அ\அ (18).wav
# Checking file: audio_dataset\அ\அ (19).wav
# Loading file: audio_dataset\அ\அ (19).wav
# Checking file: audio_dataset\அ\அ (2).wav
# Loading file: audio_dataset\அ\அ (2).wav
# Checking file: audio_dataset\அ\அ (20).wav
# Loading file: audio_dataset\அ\அ (20).wav
# Checking file: audio_dataset\அ\அ (21).wav
# Loading file: audio_dataset\அ\அ (21).wav
# Checking file: audio_dataset\அ\அ (22).wav
# Loading file: audio_dataset\அ\அ (22).wav
# Checking file: audio_dataset\அ\அ (23).wav
# Loading file: audio_dataset\அ\அ (23).wav
# Checking file: audio_dataset\அ\அ (24).wav
# Loading file: audio_dataset\அ\அ (24).wav
# Checking file: audio_dataset\அ\அ (25).wav
# Loading file: audio_dataset\அ\அ (25).wav
# Checking file: audio_dataset\அ\அ (26).wav
# Loading file: audio_dataset\அ\அ (26).wav
# Checking file: audio_dataset\அ\அ (27).wav
# Loading file: audio_dataset\அ\அ (27).wav
# Checking file: audio_dataset\அ\அ (28).wav
# Loading file: audio_dataset\அ\அ (28).wav
# Checking file: audio_dataset\அ\அ (29).wav
# Loading file: audio_dataset\அ\அ (29).wav
# Checking file: audio_dataset\அ\அ (3).wav
# Loading file: audio_dataset\அ\அ (3).wav
# Checking file: audio_dataset\அ\அ (30).wav
# Loading file: audio_dataset\அ\அ (30).wav
# Checking file: audio_dataset\அ\அ (31).wav
# Loading file: audio_dataset\அ\அ (31).wav
# Checking file: audio_dataset\அ\அ (32).wav
# Loading file: audio_dataset\அ\அ (32).wav
# Checking file: audio_dataset\அ\அ (33).wav
# Loading file: audio_dataset\அ\அ (33).wav
# Checking file: audio_dataset\அ\அ (34).wav
# Loading file: audio_dataset\அ\அ (34).wav
# Checking file: audio_dataset\அ\அ (35).wav
# Loading file: audio_dataset\அ\அ (35).wav
# Checking file: audio_dataset\அ\அ (36).wav
# Loading file: audio_dataset\அ\அ (36).wav
# Checking file: audio_dataset\அ\அ (37).wav
# Loading file: audio_dataset\அ\அ (37).wav
# Checking file: audio_dataset\அ\அ (38).wav
# Loading file: audio_dataset\அ\அ (38).wav
# Checking file: audio_dataset\அ\அ (39).wav
# Loading file: audio_dataset\அ\அ (39).wav
# Checking file: audio_dataset\அ\அ (4).wav
# Loading file: audio_dataset\அ\அ (4).wav
# Checking file: audio_dataset\அ\அ (40).wav
# Loading file: audio_dataset\அ\அ (40).wav
# Checking file: audio_dataset\அ\அ (41).wav
# Loading file: audio_dataset\அ\அ (41).wav
# Checking file: audio_dataset\அ\அ (42).wav
# Loading file: audio_dataset\அ\அ (42).wav
# Checking file: audio_dataset\அ\அ (43).wav
# Loading file: audio_dataset\அ\அ (43).wav
# Checking file: audio_dataset\அ\அ (44).wav
# Loading file: audio_dataset\அ\அ (44).wav
# Checking file: audio_dataset\அ\அ (45).wav
# Loading file: audio_dataset\அ\அ (45).wav
# Checking file: audio_dataset\அ\அ (46).wav
# Loading file: audio_dataset\அ\அ (46).wav
# Checking file: audio_dataset\அ\அ (47).wav
# Loading file: audio_dataset\அ\அ (47).wav
# Checking file: audio_dataset\அ\அ (48).wav
# Loading file: audio_dataset\அ\அ (48).wav
# Checking file: audio_dataset\அ\அ (49).wav
# Loading file: audio_dataset\அ\அ (49).wav
# Checking file: audio_dataset\அ\அ (5).wav
# Loading file: audio_dataset\அ\அ (5).wav
# Checking file: audio_dataset\அ\அ (50).wav
# Loading file: audio_dataset\அ\அ (50).wav
# Checking file: audio_dataset\அ\அ (6).wav
# Loading file: audio_dataset\அ\அ (6).wav
# Checking file: audio_dataset\அ\அ (7).wav
# Loading file: audio_dataset\அ\அ (7).wav
# Checking file: audio_dataset\அ\அ (8).wav
# Loading file: audio_dataset\அ\அ (8).wav
# Checking file: audio_dataset\அ\அ (9).wav
# Loading file: audio_dataset\அ\அ (9).wav
# Processing directory: audio_dataset\ஆ
# Checking file: audio_dataset\ஆ\old
# Skipped: audio_dataset\ஆ\old is not a valid .wav file.
# Checking file: audio_dataset\ஆ\ஆ (1).wav
# Loading file: audio_dataset\ஆ\ஆ (1).wav
# Checking file: audio_dataset\ஆ\ஆ (10).wav
# Loading file: audio_dataset\ஆ\ஆ (10).wav
# Checking file: audio_dataset\ஆ\ஆ (11).wav
# Loading file: audio_dataset\ஆ\ஆ (11).wav
# Checking file: audio_dataset\ஆ\ஆ (12).wav
# Loading file: audio_dataset\ஆ\ஆ (12).wav
# Checking file: audio_dataset\ஆ\ஆ (13).wav
# Loading file: audio_dataset\ஆ\ஆ (13).wav
# Checking file: audio_dataset\ஆ\ஆ (14).wav
# Loading file: audio_dataset\ஆ\ஆ (14).wav
# Checking file: audio_dataset\ஆ\ஆ (15).wav
# Loading file: audio_dataset\ஆ\ஆ (15).wav
# Checking file: audio_dataset\ஆ\ஆ (16).wav
# Loading file: audio_dataset\ஆ\ஆ (16).wav
# Checking file: audio_dataset\ஆ\ஆ (17).wav
# Loading file: audio_dataset\ஆ\ஆ (17).wav
# Checking file: audio_dataset\ஆ\ஆ (18).wav
# Loading file: audio_dataset\ஆ\ஆ (18).wav
# Checking file: audio_dataset\ஆ\ஆ (19).wav
# Loading file: audio_dataset\ஆ\ஆ (19).wav
# Checking file: audio_dataset\ஆ\ஆ (2).wav
# Loading file: audio_dataset\ஆ\ஆ (2).wav
# Checking file: audio_dataset\ஆ\ஆ (20).wav
# Loading file: audio_dataset\ஆ\ஆ (20).wav
# Checking file: audio_dataset\ஆ\ஆ (21).wav
# Loading file: audio_dataset\ஆ\ஆ (21).wav
# Checking file: audio_dataset\ஆ\ஆ (22).wav
# Loading file: audio_dataset\ஆ\ஆ (22).wav
# Checking file: audio_dataset\ஆ\ஆ (23).wav
# Loading file: audio_dataset\ஆ\ஆ (23).wav
# Checking file: audio_dataset\ஆ\ஆ (24).wav
# Loading file: audio_dataset\ஆ\ஆ (24).wav
# Checking file: audio_dataset\ஆ\ஆ (25).wav
# Loading file: audio_dataset\ஆ\ஆ (25).wav
# Checking file: audio_dataset\ஆ\ஆ (26).wav
# Loading file: audio_dataset\ஆ\ஆ (26).wav
# Checking file: audio_dataset\ஆ\ஆ (27).wav
# Loading file: audio_dataset\ஆ\ஆ (27).wav
# Checking file: audio_dataset\ஆ\ஆ (28).wav
# Loading file: audio_dataset\ஆ\ஆ (28).wav
# Checking file: audio_dataset\ஆ\ஆ (29).wav
# Loading file: audio_dataset\ஆ\ஆ (29).wav
# Checking file: audio_dataset\ஆ\ஆ (3).wav
# Loading file: audio_dataset\ஆ\ஆ (3).wav
# Checking file: audio_dataset\ஆ\ஆ (30).wav
# Loading file: audio_dataset\ஆ\ஆ (30).wav
# Checking file: audio_dataset\ஆ\ஆ (31).wav
# Loading file: audio_dataset\ஆ\ஆ (31).wav
# Checking file: audio_dataset\ஆ\ஆ (32).wav
# Loading file: audio_dataset\ஆ\ஆ (32).wav
# Checking file: audio_dataset\ஆ\ஆ (33).wav
# Loading file: audio_dataset\ஆ\ஆ (33).wav
# Checking file: audio_dataset\ஆ\ஆ (34).wav
# Loading file: audio_dataset\ஆ\ஆ (34).wav
# Checking file: audio_dataset\ஆ\ஆ (35).wav
# Loading file: audio_dataset\ஆ\ஆ (35).wav
# Checking file: audio_dataset\ஆ\ஆ (36).wav
# Loading file: audio_dataset\ஆ\ஆ (36).wav
# Checking file: audio_dataset\ஆ\ஆ (37).wav
# Loading file: audio_dataset\ஆ\ஆ (37).wav
# Checking file: audio_dataset\ஆ\ஆ (38).wav
# Loading file: audio_dataset\ஆ\ஆ (38).wav
# Checking file: audio_dataset\ஆ\ஆ (39).wav
# Loading file: audio_dataset\ஆ\ஆ (39).wav
# Checking file: audio_dataset\ஆ\ஆ (4).wav
# Loading file: audio_dataset\ஆ\ஆ (4).wav
# Checking file: audio_dataset\ஆ\ஆ (40).wav
# Loading file: audio_dataset\ஆ\ஆ (40).wav
# Checking file: audio_dataset\ஆ\ஆ (41).wav
# Loading file: audio_dataset\ஆ\ஆ (41).wav
# Checking file: audio_dataset\ஆ\ஆ (42).wav
# Loading file: audio_dataset\ஆ\ஆ (42).wav
# Checking file: audio_dataset\ஆ\ஆ (43).wav
# Loading file: audio_dataset\ஆ\ஆ (43).wav
# Checking file: audio_dataset\ஆ\ஆ (44).wav
# Loading file: audio_dataset\ஆ\ஆ (44).wav
# Checking file: audio_dataset\ஆ\ஆ (45).wav
# Loading file: audio_dataset\ஆ\ஆ (45).wav
# Checking file: audio_dataset\ஆ\ஆ (46).wav
# Loading file: audio_dataset\ஆ\ஆ (46).wav
# Checking file: audio_dataset\ஆ\ஆ (47).wav
# Loading file: audio_dataset\ஆ\ஆ (47).wav
# Checking file: audio_dataset\ஆ\ஆ (48).wav
# Loading file: audio_dataset\ஆ\ஆ (48).wav
# Checking file: audio_dataset\ஆ\ஆ (49).wav
# Loading file: audio_dataset\ஆ\ஆ (49).wav
# Checking file: audio_dataset\ஆ\ஆ (5).wav
# Loading file: audio_dataset\ஆ\ஆ (5).wav
# Checking file: audio_dataset\ஆ\ஆ (50).wav
# Loading file: audio_dataset\ஆ\ஆ (50).wav
# Checking file: audio_dataset\ஆ\ஆ (6).wav
# Loading file: audio_dataset\ஆ\ஆ (6).wav
# Checking file: audio_dataset\ஆ\ஆ (7).wav
# Loading file: audio_dataset\ஆ\ஆ (7).wav
# Checking file: audio_dataset\ஆ\ஆ (8).wav
# Loading file: audio_dataset\ஆ\ஆ (8).wav
# Checking file: audio_dataset\ஆ\ஆ (9).wav
# Loading file: audio_dataset\ஆ\ஆ (9).wav
# Processing directory: audio_dataset\இ
# Checking file: audio_dataset\இ\old
# Skipped: audio_dataset\இ\old is not a valid .wav file.
# Checking file: audio_dataset\இ\இ (1).wav
# Loading file: audio_dataset\இ\இ (1).wav
# Checking file: audio_dataset\இ\இ (10).wav
# Loading file: audio_dataset\இ\இ (10).wav
# Checking file: audio_dataset\இ\இ (11).wav
# Loading file: audio_dataset\இ\இ (11).wav
# Checking file: audio_dataset\இ\இ (12).wav
# Loading file: audio_dataset\இ\இ (12).wav
# Checking file: audio_dataset\இ\இ (13).wav
# Loading file: audio_dataset\இ\இ (13).wav
# Checking file: audio_dataset\இ\இ (14).wav
# Loading file: audio_dataset\இ\இ (14).wav
# Checking file: audio_dataset\இ\இ (15).wav
# Loading file: audio_dataset\இ\இ (15).wav
# Checking file: audio_dataset\இ\இ (16).wav
# Loading file: audio_dataset\இ\இ (16).wav
# Checking file: audio_dataset\இ\இ (17).wav
# Loading file: audio_dataset\இ\இ (17).wav
# Checking file: audio_dataset\இ\இ (18).wav
# Loading file: audio_dataset\இ\இ (18).wav
# Checking file: audio_dataset\இ\இ (19).wav
# Loading file: audio_dataset\இ\இ (19).wav
# Checking file: audio_dataset\இ\இ (2).wav
# Loading file: audio_dataset\இ\இ (2).wav
# Checking file: audio_dataset\இ\இ (20).wav
# Loading file: audio_dataset\இ\இ (20).wav
# Checking file: audio_dataset\இ\இ (21).wav
# Loading file: audio_dataset\இ\இ (21).wav
# Checking file: audio_dataset\இ\இ (22).wav
# Loading file: audio_dataset\இ\இ (22).wav
# Checking file: audio_dataset\இ\இ (23).wav
# Loading file: audio_dataset\இ\இ (23).wav
# Checking file: audio_dataset\இ\இ (24).wav
# Loading file: audio_dataset\இ\இ (24).wav
# Checking file: audio_dataset\இ\இ (25).wav
# Loading file: audio_dataset\இ\இ (25).wav
# Checking file: audio_dataset\இ\இ (26).wav
# Loading file: audio_dataset\இ\இ (26).wav
# Checking file: audio_dataset\இ\இ (27).wav
# Loading file: audio_dataset\இ\இ (27).wav
# Checking file: audio_dataset\இ\இ (28).wav
# Loading file: audio_dataset\இ\இ (28).wav
# Checking file: audio_dataset\இ\இ (29).wav
# Loading file: audio_dataset\இ\இ (29).wav
# Checking file: audio_dataset\இ\இ (3).wav
# Loading file: audio_dataset\இ\இ (3).wav
# Checking file: audio_dataset\இ\இ (30).wav
# Loading file: audio_dataset\இ\இ (30).wav
# Checking file: audio_dataset\இ\இ (31).wav
# Loading file: audio_dataset\இ\இ (31).wav
# Checking file: audio_dataset\இ\இ (32).wav
# Loading file: audio_dataset\இ\இ (32).wav
# Checking file: audio_dataset\இ\இ (33).wav
# Loading file: audio_dataset\இ\இ (33).wav
# Checking file: audio_dataset\இ\இ (34).wav
# Loading file: audio_dataset\இ\இ (34).wav
# Checking file: audio_dataset\இ\இ (35).wav
# Loading file: audio_dataset\இ\இ (35).wav
# Checking file: audio_dataset\இ\இ (36).wav
# Loading file: audio_dataset\இ\இ (36).wav
# Checking file: audio_dataset\இ\இ (37).wav
# Loading file: audio_dataset\இ\இ (37).wav
# Checking file: audio_dataset\இ\இ (38).wav
# Loading file: audio_dataset\இ\இ (38).wav
# Checking file: audio_dataset\இ\இ (39).wav
# Loading file: audio_dataset\இ\இ (39).wav
# Checking file: audio_dataset\இ\இ (4).wav
# Loading file: audio_dataset\இ\இ (4).wav
# Checking file: audio_dataset\இ\இ (40).wav
# Loading file: audio_dataset\இ\இ (40).wav
# Checking file: audio_dataset\இ\இ (41).wav
# Loading file: audio_dataset\இ\இ (41).wav
# Checking file: audio_dataset\இ\இ (42).wav
# Loading file: audio_dataset\இ\இ (42).wav
# Checking file: audio_dataset\இ\இ (43).wav
# Loading file: audio_dataset\இ\இ (43).wav
# Checking file: audio_dataset\இ\இ (44).wav
# Loading file: audio_dataset\இ\இ (44).wav
# Checking file: audio_dataset\இ\இ (45).wav
# Loading file: audio_dataset\இ\இ (45).wav
# Checking file: audio_dataset\இ\இ (46).wav
# Loading file: audio_dataset\இ\இ (46).wav
# Checking file: audio_dataset\இ\இ (47).wav
# Loading file: audio_dataset\இ\இ (47).wav
# Checking file: audio_dataset\இ\இ (48).wav
# Loading file: audio_dataset\இ\இ (48).wav
# Checking file: audio_dataset\இ\இ (49).wav
# Loading file: audio_dataset\இ\இ (49).wav
# Checking file: audio_dataset\இ\இ (5).wav
# Loading file: audio_dataset\இ\இ (5).wav
# Checking file: audio_dataset\இ\இ (50).wav
# Loading file: audio_dataset\இ\இ (50).wav
# Checking file: audio_dataset\இ\இ (6).wav
# Loading file: audio_dataset\இ\இ (6).wav
# Checking file: audio_dataset\இ\இ (7).wav
# Loading file: audio_dataset\இ\இ (7).wav
# Checking file: audio_dataset\இ\இ (8).wav
# Loading file: audio_dataset\இ\இ (8).wav
# Checking file: audio_dataset\இ\இ (9).wav
# Loading file: audio_dataset\இ\இ (9).wav
# Processing directory: audio_dataset\ஈ
# Checking file: audio_dataset\ஈ\old
# Skipped: audio_dataset\ஈ\old is not a valid .wav file.
# Checking file: audio_dataset\ஈ\ஈ (1).wav
# Loading file: audio_dataset\ஈ\ஈ (1).wav
# Checking file: audio_dataset\ஈ\ஈ (10).wav
# Loading file: audio_dataset\ஈ\ஈ (10).wav
# Checking file: audio_dataset\ஈ\ஈ (11).wav
# Loading file: audio_dataset\ஈ\ஈ (11).wav
# Checking file: audio_dataset\ஈ\ஈ (12).wav
# Loading file: audio_dataset\ஈ\ஈ (12).wav
# Checking file: audio_dataset\ஈ\ஈ (13).wav
# Loading file: audio_dataset\ஈ\ஈ (13).wav
# Checking file: audio_dataset\ஈ\ஈ (14).wav
# Loading file: audio_dataset\ஈ\ஈ (14).wav
# Checking file: audio_dataset\ஈ\ஈ (15).wav
# Loading file: audio_dataset\ஈ\ஈ (15).wav
# Checking file: audio_dataset\ஈ\ஈ (16).wav
# Loading file: audio_dataset\ஈ\ஈ (16).wav
# Checking file: audio_dataset\ஈ\ஈ (17).wav
# Loading file: audio_dataset\ஈ\ஈ (17).wav
# Checking file: audio_dataset\ஈ\ஈ (18).wav
# Loading file: audio_dataset\ஈ\ஈ (18).wav
# Checking file: audio_dataset\ஈ\ஈ (19).wav
# Loading file: audio_dataset\ஈ\ஈ (19).wav
# Checking file: audio_dataset\ஈ\ஈ (2).wav
# Loading file: audio_dataset\ஈ\ஈ (2).wav
# Checking file: audio_dataset\ஈ\ஈ (20).wav
# Loading file: audio_dataset\ஈ\ஈ (20).wav
# Checking file: audio_dataset\ஈ\ஈ (21).wav
# Loading file: audio_dataset\ஈ\ஈ (21).wav
# Checking file: audio_dataset\ஈ\ஈ (22).wav
# Loading file: audio_dataset\ஈ\ஈ (22).wav
# Checking file: audio_dataset\ஈ\ஈ (23).wav
# Loading file: audio_dataset\ஈ\ஈ (23).wav
# Checking file: audio_dataset\ஈ\ஈ (24).wav
# Loading file: audio_dataset\ஈ\ஈ (24).wav
# Checking file: audio_dataset\ஈ\ஈ (25).wav
# Loading file: audio_dataset\ஈ\ஈ (25).wav
# Checking file: audio_dataset\ஈ\ஈ (26).wav
# Loading file: audio_dataset\ஈ\ஈ (26).wav
# Checking file: audio_dataset\ஈ\ஈ (27).wav
# Loading file: audio_dataset\ஈ\ஈ (27).wav
# Checking file: audio_dataset\ஈ\ஈ (28).wav
# Loading file: audio_dataset\ஈ\ஈ (28).wav
# Checking file: audio_dataset\ஈ\ஈ (29).wav
# Loading file: audio_dataset\ஈ\ஈ (29).wav
# Checking file: audio_dataset\ஈ\ஈ (3).wav
# Loading file: audio_dataset\ஈ\ஈ (3).wav
# Checking file: audio_dataset\ஈ\ஈ (30).wav
# Loading file: audio_dataset\ஈ\ஈ (30).wav
# Checking file: audio_dataset\ஈ\ஈ (31).wav
# Loading file: audio_dataset\ஈ\ஈ (31).wav
# Checking file: audio_dataset\ஈ\ஈ (32).wav
# Loading file: audio_dataset\ஈ\ஈ (32).wav
# Checking file: audio_dataset\ஈ\ஈ (33).wav
# Loading file: audio_dataset\ஈ\ஈ (33).wav
# Checking file: audio_dataset\ஈ\ஈ (34).wav
# Loading file: audio_dataset\ஈ\ஈ (34).wav
# Checking file: audio_dataset\ஈ\ஈ (35).wav
# Loading file: audio_dataset\ஈ\ஈ (35).wav
# Checking file: audio_dataset\ஈ\ஈ (36).wav
# Loading file: audio_dataset\ஈ\ஈ (36).wav
# Checking file: audio_dataset\ஈ\ஈ (37).wav
# Loading file: audio_dataset\ஈ\ஈ (37).wav
# Checking file: audio_dataset\ஈ\ஈ (38).wav
# Loading file: audio_dataset\ஈ\ஈ (38).wav
# Checking file: audio_dataset\ஈ\ஈ (39).wav
# Loading file: audio_dataset\ஈ\ஈ (39).wav
# Checking file: audio_dataset\ஈ\ஈ (4).wav
# Loading file: audio_dataset\ஈ\ஈ (4).wav
# Checking file: audio_dataset\ஈ\ஈ (40).wav
# Loading file: audio_dataset\ஈ\ஈ (40).wav
# Checking file: audio_dataset\ஈ\ஈ (41).wav
# Loading file: audio_dataset\ஈ\ஈ (41).wav
# Checking file: audio_dataset\ஈ\ஈ (42).wav
# Loading file: audio_dataset\ஈ\ஈ (42).wav
# Checking file: audio_dataset\ஈ\ஈ (43).wav
# Loading file: audio_dataset\ஈ\ஈ (43).wav
# Checking file: audio_dataset\ஈ\ஈ (44).wav
# Loading file: audio_dataset\ஈ\ஈ (44).wav
# Checking file: audio_dataset\ஈ\ஈ (45).wav
# Loading file: audio_dataset\ஈ\ஈ (45).wav
# Checking file: audio_dataset\ஈ\ஈ (46).wav
# Loading file: audio_dataset\ஈ\ஈ (46).wav
# Checking file: audio_dataset\ஈ\ஈ (47).wav
# Loading file: audio_dataset\ஈ\ஈ (47).wav
# Checking file: audio_dataset\ஈ\ஈ (48).wav
# Loading file: audio_dataset\ஈ\ஈ (48).wav
# Checking file: audio_dataset\ஈ\ஈ (49).wav
# Loading file: audio_dataset\ஈ\ஈ (49).wav
# Checking file: audio_dataset\ஈ\ஈ (5).wav
# Loading file: audio_dataset\ஈ\ஈ (5).wav
# Checking file: audio_dataset\ஈ\ஈ (50).wav
# Loading file: audio_dataset\ஈ\ஈ (50).wav
# Checking file: audio_dataset\ஈ\ஈ (6).wav
# Loading file: audio_dataset\ஈ\ஈ (6).wav
# Checking file: audio_dataset\ஈ\ஈ (7).wav
# Loading file: audio_dataset\ஈ\ஈ (7).wav
# Checking file: audio_dataset\ஈ\ஈ (8).wav
# Loading file: audio_dataset\ஈ\ஈ (8).wav
# Checking file: audio_dataset\ஈ\ஈ (9).wav
# Loading file: audio_dataset\ஈ\ஈ (9).wav
# Processing directory: audio_dataset\உ
# Checking file: audio_dataset\உ\old
# Skipped: audio_dataset\உ\old is not a valid .wav file.
# Checking file: audio_dataset\உ\உ (1).wav
# Loading file: audio_dataset\உ\உ (1).wav
# Checking file: audio_dataset\உ\உ (10).wav
# Loading file: audio_dataset\உ\உ (10).wav
# Checking file: audio_dataset\உ\உ (11).wav
# Loading file: audio_dataset\உ\உ (11).wav
# Checking file: audio_dataset\உ\உ (12).wav
# Loading file: audio_dataset\உ\உ (12).wav
# Checking file: audio_dataset\உ\உ (13).wav
# Loading file: audio_dataset\உ\உ (13).wav
# Checking file: audio_dataset\உ\உ (14).wav
# Loading file: audio_dataset\உ\உ (14).wav
# Checking file: audio_dataset\உ\உ (15).wav
# Loading file: audio_dataset\உ\உ (15).wav
# Checking file: audio_dataset\உ\உ (16).wav
# Loading file: audio_dataset\உ\உ (16).wav
# Checking file: audio_dataset\உ\உ (17).wav
# Loading file: audio_dataset\உ\உ (17).wav
# Checking file: audio_dataset\உ\உ (18).wav
# Loading file: audio_dataset\உ\உ (18).wav
# Checking file: audio_dataset\உ\உ (19).wav
# Loading file: audio_dataset\உ\உ (19).wav
# Checking file: audio_dataset\உ\உ (2).wav
# Loading file: audio_dataset\உ\உ (2).wav
# Checking file: audio_dataset\உ\உ (20).wav
# Loading file: audio_dataset\உ\உ (20).wav
# Checking file: audio_dataset\உ\உ (21).wav
# Loading file: audio_dataset\உ\உ (21).wav
# Checking file: audio_dataset\உ\உ (22).wav
# Loading file: audio_dataset\உ\உ (22).wav
# Checking file: audio_dataset\உ\உ (23).wav
# Loading file: audio_dataset\உ\உ (23).wav
# Checking file: audio_dataset\உ\உ (24).wav
# Loading file: audio_dataset\உ\உ (24).wav
# Checking file: audio_dataset\உ\உ (25).wav
# Loading file: audio_dataset\உ\உ (25).wav
# Checking file: audio_dataset\உ\உ (26).wav
# Loading file: audio_dataset\உ\உ (26).wav
# Checking file: audio_dataset\உ\உ (27).wav
# Loading file: audio_dataset\உ\உ (27).wav
# Checking file: audio_dataset\உ\உ (28).wav
# Loading file: audio_dataset\உ\உ (28).wav
# Checking file: audio_dataset\உ\உ (29).wav
# Loading file: audio_dataset\உ\உ (29).wav
# Checking file: audio_dataset\உ\உ (3).wav
# Loading file: audio_dataset\உ\உ (3).wav
# Checking file: audio_dataset\உ\உ (30).wav
# Loading file: audio_dataset\உ\உ (30).wav
# Checking file: audio_dataset\உ\உ (31).wav
# Loading file: audio_dataset\உ\உ (31).wav
# Checking file: audio_dataset\உ\உ (32).wav
# Loading file: audio_dataset\உ\உ (32).wav
# Checking file: audio_dataset\உ\உ (33).wav
# Loading file: audio_dataset\உ\உ (33).wav
# Checking file: audio_dataset\உ\உ (34).wav
# Loading file: audio_dataset\உ\உ (34).wav
# Checking file: audio_dataset\உ\உ (35).wav
# Loading file: audio_dataset\உ\உ (35).wav
# Checking file: audio_dataset\உ\உ (36).wav
# Loading file: audio_dataset\உ\உ (36).wav
# Checking file: audio_dataset\உ\உ (37).wav
# Loading file: audio_dataset\உ\உ (37).wav
# Checking file: audio_dataset\உ\உ (38).wav
# Loading file: audio_dataset\உ\உ (38).wav
# Checking file: audio_dataset\உ\உ (39).wav
# Loading file: audio_dataset\உ\உ (39).wav
# Checking file: audio_dataset\உ\உ (4).wav
# Loading file: audio_dataset\உ\உ (4).wav
# Checking file: audio_dataset\உ\உ (40).wav
# Loading file: audio_dataset\உ\உ (40).wav
# Checking file: audio_dataset\உ\உ (41).wav
# Loading file: audio_dataset\உ\உ (41).wav
# Checking file: audio_dataset\உ\உ (42).wav
# Loading file: audio_dataset\உ\உ (42).wav
# Checking file: audio_dataset\உ\உ (43).wav
# Loading file: audio_dataset\உ\உ (43).wav
# Checking file: audio_dataset\உ\உ (44).wav
# Loading file: audio_dataset\உ\உ (44).wav
# Checking file: audio_dataset\உ\உ (45).wav
# Loading file: audio_dataset\உ\உ (45).wav
# Checking file: audio_dataset\உ\உ (46).wav
# Loading file: audio_dataset\உ\உ (46).wav
# Checking file: audio_dataset\உ\உ (47).wav
# Loading file: audio_dataset\உ\உ (47).wav
# Checking file: audio_dataset\உ\உ (48).wav
# Loading file: audio_dataset\உ\உ (48).wav
# Checking file: audio_dataset\உ\உ (49).wav
# Loading file: audio_dataset\உ\உ (49).wav
# Checking file: audio_dataset\உ\உ (5).wav
# Loading file: audio_dataset\உ\உ (5).wav
# Checking file: audio_dataset\உ\உ (50).wav
# Loading file: audio_dataset\உ\உ (50).wav
# Checking file: audio_dataset\உ\உ (6).wav
# Loading file: audio_dataset\உ\உ (6).wav
# Checking file: audio_dataset\உ\உ (7).wav
# Loading file: audio_dataset\உ\உ (7).wav
# Checking file: audio_dataset\உ\உ (8).wav
# Loading file: audio_dataset\உ\உ (8).wav
# Checking file: audio_dataset\உ\உ (9).wav
# Loading file: audio_dataset\உ\உ (9).wav
# Processing directory: audio_dataset\ஊ
# Checking file: audio_dataset\ஊ\old
# Skipped: audio_dataset\ஊ\old is not a valid .wav file.
# Checking file: audio_dataset\ஊ\ஊ (1).wav
# Loading file: audio_dataset\ஊ\ஊ (1).wav
# Checking file: audio_dataset\ஊ\ஊ (10).wav
# Loading file: audio_dataset\ஊ\ஊ (10).wav
# Checking file: audio_dataset\ஊ\ஊ (11).wav
# Loading file: audio_dataset\ஊ\ஊ (11).wav
# Checking file: audio_dataset\ஊ\ஊ (12).wav
# Loading file: audio_dataset\ஊ\ஊ (12).wav
# Checking file: audio_dataset\ஊ\ஊ (13).wav
# Loading file: audio_dataset\ஊ\ஊ (13).wav
# Checking file: audio_dataset\ஊ\ஊ (14).wav
# Loading file: audio_dataset\ஊ\ஊ (14).wav
# Checking file: audio_dataset\ஊ\ஊ (15).wav
# Loading file: audio_dataset\ஊ\ஊ (15).wav
# Checking file: audio_dataset\ஊ\ஊ (16).wav
# Loading file: audio_dataset\ஊ\ஊ (16).wav
# Checking file: audio_dataset\ஊ\ஊ (17).wav
# Loading file: audio_dataset\ஊ\ஊ (17).wav
# Checking file: audio_dataset\ஊ\ஊ (18).wav
# Loading file: audio_dataset\ஊ\ஊ (18).wav
# Checking file: audio_dataset\ஊ\ஊ (19).wav
# Loading file: audio_dataset\ஊ\ஊ (19).wav
# Checking file: audio_dataset\ஊ\ஊ (2).wav
# Loading file: audio_dataset\ஊ\ஊ (2).wav
# Checking file: audio_dataset\ஊ\ஊ (20).wav
# Loading file: audio_dataset\ஊ\ஊ (20).wav
# Checking file: audio_dataset\ஊ\ஊ (21).wav
# Loading file: audio_dataset\ஊ\ஊ (21).wav
# Checking file: audio_dataset\ஊ\ஊ (22).wav
# Loading file: audio_dataset\ஊ\ஊ (22).wav
# Checking file: audio_dataset\ஊ\ஊ (23).wav
# Loading file: audio_dataset\ஊ\ஊ (23).wav
# Checking file: audio_dataset\ஊ\ஊ (24).wav
# Loading file: audio_dataset\ஊ\ஊ (24).wav
# Checking file: audio_dataset\ஊ\ஊ (25).wav
# Loading file: audio_dataset\ஊ\ஊ (25).wav
# Checking file: audio_dataset\ஊ\ஊ (26).wav
# Loading file: audio_dataset\ஊ\ஊ (26).wav
# Checking file: audio_dataset\ஊ\ஊ (27).wav
# Loading file: audio_dataset\ஊ\ஊ (27).wav
# Checking file: audio_dataset\ஊ\ஊ (28).wav
# Loading file: audio_dataset\ஊ\ஊ (28).wav
# Checking file: audio_dataset\ஊ\ஊ (29).wav
# Loading file: audio_dataset\ஊ\ஊ (29).wav
# Checking file: audio_dataset\ஊ\ஊ (3).wav
# Loading file: audio_dataset\ஊ\ஊ (3).wav
# Checking file: audio_dataset\ஊ\ஊ (30).wav
# Loading file: audio_dataset\ஊ\ஊ (30).wav
# Checking file: audio_dataset\ஊ\ஊ (31).wav
# Loading file: audio_dataset\ஊ\ஊ (31).wav
# Checking file: audio_dataset\ஊ\ஊ (32).wav
# Loading file: audio_dataset\ஊ\ஊ (32).wav
# Checking file: audio_dataset\ஊ\ஊ (33).wav
# Loading file: audio_dataset\ஊ\ஊ (33).wav
# Checking file: audio_dataset\ஊ\ஊ (34).wav
# Loading file: audio_dataset\ஊ\ஊ (34).wav
# Checking file: audio_dataset\ஊ\ஊ (35).wav
# Loading file: audio_dataset\ஊ\ஊ (35).wav
# Checking file: audio_dataset\ஊ\ஊ (36).wav
# Loading file: audio_dataset\ஊ\ஊ (36).wav
# Checking file: audio_dataset\ஊ\ஊ (37).wav
# Loading file: audio_dataset\ஊ\ஊ (37).wav
# Checking file: audio_dataset\ஊ\ஊ (38).wav
# Loading file: audio_dataset\ஊ\ஊ (38).wav
# Checking file: audio_dataset\ஊ\ஊ (39).wav
# Loading file: audio_dataset\ஊ\ஊ (39).wav
# Checking file: audio_dataset\ஊ\ஊ (4).wav
# Loading file: audio_dataset\ஊ\ஊ (4).wav
# Checking file: audio_dataset\ஊ\ஊ (40).wav
# Loading file: audio_dataset\ஊ\ஊ (40).wav
# Checking file: audio_dataset\ஊ\ஊ (41).wav
# Loading file: audio_dataset\ஊ\ஊ (41).wav
# Checking file: audio_dataset\ஊ\ஊ (42).wav
# Loading file: audio_dataset\ஊ\ஊ (42).wav
# Checking file: audio_dataset\ஊ\ஊ (43).wav
# Loading file: audio_dataset\ஊ\ஊ (43).wav
# Checking file: audio_dataset\ஊ\ஊ (44).wav
# Loading file: audio_dataset\ஊ\ஊ (44).wav
# Checking file: audio_dataset\ஊ\ஊ (45).wav
# Loading file: audio_dataset\ஊ\ஊ (45).wav
# Checking file: audio_dataset\ஊ\ஊ (46).wav
# Loading file: audio_dataset\ஊ\ஊ (46).wav
# Checking file: audio_dataset\ஊ\ஊ (47).wav
# Loading file: audio_dataset\ஊ\ஊ (47).wav
# Checking file: audio_dataset\ஊ\ஊ (48).wav
# Loading file: audio_dataset\ஊ\ஊ (48).wav
# Checking file: audio_dataset\ஊ\ஊ (49).wav
# Loading file: audio_dataset\ஊ\ஊ (49).wav
# Checking file: audio_dataset\ஊ\ஊ (5).wav
# Loading file: audio_dataset\ஊ\ஊ (5).wav
# Checking file: audio_dataset\ஊ\ஊ (50).wav
# Loading file: audio_dataset\ஊ\ஊ (50).wav
# Checking file: audio_dataset\ஊ\ஊ (6).wav
# Loading file: audio_dataset\ஊ\ஊ (6).wav
# Checking file: audio_dataset\ஊ\ஊ (7).wav
# Loading file: audio_dataset\ஊ\ஊ (7).wav
# Checking file: audio_dataset\ஊ\ஊ (8).wav
# Loading file: audio_dataset\ஊ\ஊ (8).wav
# Checking file: audio_dataset\ஊ\ஊ (9).wav
# Loading file: audio_dataset\ஊ\ஊ (9).wav
# Processing directory: audio_dataset\எ
# Checking file: audio_dataset\எ\old
# Skipped: audio_dataset\எ\old is not a valid .wav file.
# Checking file: audio_dataset\எ\எ (1).wav
# Loading file: audio_dataset\எ\எ (1).wav
# Checking file: audio_dataset\எ\எ (10).wav
# Loading file: audio_dataset\எ\எ (10).wav
# Checking file: audio_dataset\எ\எ (11).wav
# Loading file: audio_dataset\எ\எ (11).wav
# Checking file: audio_dataset\எ\எ (12).wav
# Loading file: audio_dataset\எ\எ (12).wav
# Checking file: audio_dataset\எ\எ (13).wav
# Loading file: audio_dataset\எ\எ (13).wav
# Checking file: audio_dataset\எ\எ (14).wav
# Loading file: audio_dataset\எ\எ (14).wav
# Checking file: audio_dataset\எ\எ (15).wav
# Loading file: audio_dataset\எ\எ (15).wav
# Checking file: audio_dataset\எ\எ (16).wav
# Loading file: audio_dataset\எ\எ (16).wav
# Checking file: audio_dataset\எ\எ (17).wav
# Loading file: audio_dataset\எ\எ (17).wav
# Checking file: audio_dataset\எ\எ (18).wav
# Loading file: audio_dataset\எ\எ (18).wav
# Checking file: audio_dataset\எ\எ (19).wav
# Loading file: audio_dataset\எ\எ (19).wav
# Checking file: audio_dataset\எ\எ (2).wav
# Loading file: audio_dataset\எ\எ (2).wav
# Checking file: audio_dataset\எ\எ (20).wav
# Loading file: audio_dataset\எ\எ (20).wav
# Checking file: audio_dataset\எ\எ (21).wav
# Loading file: audio_dataset\எ\எ (21).wav
# Checking file: audio_dataset\எ\எ (22).wav
# Loading file: audio_dataset\எ\எ (22).wav
# Checking file: audio_dataset\எ\எ (23).wav
# Loading file: audio_dataset\எ\எ (23).wav
# Checking file: audio_dataset\எ\எ (24).wav
# Loading file: audio_dataset\எ\எ (24).wav
# Checking file: audio_dataset\எ\எ (25).wav
# Loading file: audio_dataset\எ\எ (25).wav
# Checking file: audio_dataset\எ\எ (26).wav
# Loading file: audio_dataset\எ\எ (26).wav
# Checking file: audio_dataset\எ\எ (27).wav
# Loading file: audio_dataset\எ\எ (27).wav
# Checking file: audio_dataset\எ\எ (28).wav
# Loading file: audio_dataset\எ\எ (28).wav
# Checking file: audio_dataset\எ\எ (29).wav
# Loading file: audio_dataset\எ\எ (29).wav
# Checking file: audio_dataset\எ\எ (3).wav
# Loading file: audio_dataset\எ\எ (3).wav
# Checking file: audio_dataset\எ\எ (30).wav
# Loading file: audio_dataset\எ\எ (30).wav
# Checking file: audio_dataset\எ\எ (31).wav
# Loading file: audio_dataset\எ\எ (31).wav
# Checking file: audio_dataset\எ\எ (32).wav
# Loading file: audio_dataset\எ\எ (32).wav
# Checking file: audio_dataset\எ\எ (33).wav
# Loading file: audio_dataset\எ\எ (33).wav
# Checking file: audio_dataset\எ\எ (34).wav
# Loading file: audio_dataset\எ\எ (34).wav
# Checking file: audio_dataset\எ\எ (35).wav
# Loading file: audio_dataset\எ\எ (35).wav
# Checking file: audio_dataset\எ\எ (36).wav
# Loading file: audio_dataset\எ\எ (36).wav
# Checking file: audio_dataset\எ\எ (37).wav
# Loading file: audio_dataset\எ\எ (37).wav
# Checking file: audio_dataset\எ\எ (38).wav
# Loading file: audio_dataset\எ\எ (38).wav
# Checking file: audio_dataset\எ\எ (39).wav
# Loading file: audio_dataset\எ\எ (39).wav
# Checking file: audio_dataset\எ\எ (4).wav
# Loading file: audio_dataset\எ\எ (4).wav
# Checking file: audio_dataset\எ\எ (40).wav
# Loading file: audio_dataset\எ\எ (40).wav
# Checking file: audio_dataset\எ\எ (41).wav
# Loading file: audio_dataset\எ\எ (41).wav
# Checking file: audio_dataset\எ\எ (42).wav
# Loading file: audio_dataset\எ\எ (42).wav
# Checking file: audio_dataset\எ\எ (43).wav
# Loading file: audio_dataset\எ\எ (43).wav
# Checking file: audio_dataset\எ\எ (44).wav
# Loading file: audio_dataset\எ\எ (44).wav
# Checking file: audio_dataset\எ\எ (45).wav
# Loading file: audio_dataset\எ\எ (45).wav
# Checking file: audio_dataset\எ\எ (46).wav
# Loading file: audio_dataset\எ\எ (46).wav
# Checking file: audio_dataset\எ\எ (47).wav
# Loading file: audio_dataset\எ\எ (47).wav
# Checking file: audio_dataset\எ\எ (48).wav
# Loading file: audio_dataset\எ\எ (48).wav
# Checking file: audio_dataset\எ\எ (49).wav
# Loading file: audio_dataset\எ\எ (49).wav
# Checking file: audio_dataset\எ\எ (5).wav
# Loading file: audio_dataset\எ\எ (5).wav
# Checking file: audio_dataset\எ\எ (50).wav
# Loading file: audio_dataset\எ\எ (50).wav
# Checking file: audio_dataset\எ\எ (6).wav
# Loading file: audio_dataset\எ\எ (6).wav
# Checking file: audio_dataset\எ\எ (7).wav
# Loading file: audio_dataset\எ\எ (7).wav
# Checking file: audio_dataset\எ\எ (8).wav
# Loading file: audio_dataset\எ\எ (8).wav
# Checking file: audio_dataset\எ\எ (9).wav
# Loading file: audio_dataset\எ\எ (9).wav
# Processing directory: audio_dataset\ஏ
# Checking file: audio_dataset\ஏ\old
# Skipped: audio_dataset\ஏ\old is not a valid .wav file.
# Checking file: audio_dataset\ஏ\ஏ (1).wav
# Loading file: audio_dataset\ஏ\ஏ (1).wav
# Checking file: audio_dataset\ஏ\ஏ (10).wav
# Loading file: audio_dataset\ஏ\ஏ (10).wav
# Checking file: audio_dataset\ஏ\ஏ (11).wav
# Loading file: audio_dataset\ஏ\ஏ (11).wav
# Checking file: audio_dataset\ஏ\ஏ (12).wav
# Loading file: audio_dataset\ஏ\ஏ (12).wav
# Checking file: audio_dataset\ஏ\ஏ (13).wav
# Loading file: audio_dataset\ஏ\ஏ (13).wav
# Checking file: audio_dataset\ஏ\ஏ (14).wav
# Loading file: audio_dataset\ஏ\ஏ (14).wav
# Checking file: audio_dataset\ஏ\ஏ (15).wav
# Loading file: audio_dataset\ஏ\ஏ (15).wav
# Checking file: audio_dataset\ஏ\ஏ (16).wav
# Loading file: audio_dataset\ஏ\ஏ (16).wav
# Checking file: audio_dataset\ஏ\ஏ (17).wav
# Loading file: audio_dataset\ஏ\ஏ (17).wav
# Checking file: audio_dataset\ஏ\ஏ (18).wav
# Loading file: audio_dataset\ஏ\ஏ (18).wav
# Checking file: audio_dataset\ஏ\ஏ (19).wav
# Loading file: audio_dataset\ஏ\ஏ (19).wav
# Checking file: audio_dataset\ஏ\ஏ (2).wav
# Loading file: audio_dataset\ஏ\ஏ (2).wav
# Checking file: audio_dataset\ஏ\ஏ (20).wav
# Loading file: audio_dataset\ஏ\ஏ (20).wav
# Checking file: audio_dataset\ஏ\ஏ (21).wav
# Loading file: audio_dataset\ஏ\ஏ (21).wav
# Checking file: audio_dataset\ஏ\ஏ (22).wav
# ...
# Loading file: audio_dataset\ஒ\ஒ (7).wav
# Checking file: audio_dataset\ஒ\ஒ (8).wav
# Loading file: audio_dataset\ஒ\ஒ (8).wav
# Checking file: audio_dataset\ஒ\ஒ (9).wav
# Loading file: audio_dataset\ஒ\ஒ (9).wav
# Processing directory: audio_dataset\ஓ
# Checking file: audio_dataset\ஓ\old
# Skipped: audio_dataset\ஓ\old is not a valid .wav file.
# Checking file: audio_dataset\ஓ\ஓ (1).wav
# Loading file: audio_dataset\ஓ\ஓ (1).wav
# Checking file: audio_dataset\ஓ\ஓ (10).wav
# Loading file: audio_dataset\ஓ\ஓ (10).wav
# Checking file: audio_dataset\ஓ\ஓ (11).wav
# Loading file: audio_dataset\ஓ\ஓ (11).wav
# Checking file: audio_dataset\ஓ\ஓ (12).wav
# Loading file: audio_dataset\ஓ\ஓ (12).wav
# Checking file: audio_dataset\ஓ\ஓ (13).wav
# Loading file: audio_dataset\ஓ\ஓ (13).wav
# Checking file: audio_dataset\ஓ\ஓ (14).wav
# Loading file: audio_dataset\ஓ\ஓ (14).wav
# Checking file: audio_dataset\ஓ\ஓ (15).wav
# Loading file: audio_dataset\ஓ\ஓ (15).wav
# Checking file: audio_dataset\ஓ\ஓ (16).wav
# Loading file: audio_dataset\ஓ\ஓ (16).wav
# Checking file: audio_dataset\ஓ\ஓ (17).wav
# Loading file: audio_dataset\ஓ\ஓ (17).wav
# Checking file: audio_dataset\ஓ\ஓ (18).wav
# Loading file: audio_dataset\ஓ\ஓ (18).wav
# Checking file: audio_dataset\ஓ\ஓ (19).wav
# Loading file: audio_dataset\ஓ\ஓ (19).wav
# Checking file: audio_dataset\ஓ\ஓ (2).wav
# Loading file: audio_dataset\ஓ\ஓ (2).wav
# Checking file: audio_dataset\ஓ\ஓ (20).wav
# Loading file: audio_dataset\ஓ\ஓ (20).wav
# Checking file: audio_dataset\ஓ\ஓ (21).wav
# Loading file: audio_dataset\ஓ\ஓ (21).wav
# Checking file: audio_dataset\ஓ\ஓ (22).wav
# Loading file: audio_dataset\ஓ\ஓ (22).wav
# Checking file: audio_dataset\ஓ\ஓ (23).wav
# Loading file: audio_dataset\ஓ\ஓ (23).wav
# Checking file: audio_dataset\ஓ\ஓ (24).wav
# Loading file: audio_dataset\ஓ\ஓ (24).wav
# Checking file: audio_dataset\ஓ\ஓ (25).wav
# Loading file: audio_dataset\ஓ\ஓ (25).wav
# Checking file: audio_dataset\ஓ\ஓ (26).wav
# Loading file: audio_dataset\ஓ\ஓ (26).wav
# Checking file: audio_dataset\ஓ\ஓ (27).wav
# Loading file: audio_dataset\ஓ\ஓ (27).wav
# Checking file: audio_dataset\ஓ\ஓ (28).wav
# Loading file: audio_dataset\ஓ\ஓ (28).wav
# Checking file: audio_dataset\ஓ\ஓ (29).wav
# Loading file: audio_dataset\ஓ\ஓ (29).wav
# Checking file: audio_dataset\ஓ\ஓ (3).wav
# Loading file: audio_dataset\ஓ\ஓ (3).wav
# Checking file: audio_dataset\ஓ\ஓ (30).wav
# Loading file: audio_dataset\ஓ\ஓ (30).wav
# Checking file: audio_dataset\ஓ\ஓ (31).wav
# Loading file: audio_dataset\ஓ\ஓ (31).wav
# Checking file: audio_dataset\ஓ\ஓ (32).wav
# Loading file: audio_dataset\ஓ\ஓ (32).wav
# Checking file: audio_dataset\ஓ\ஓ (33).wav
# Loading file: audio_dataset\ஓ\ஓ (33).wav
# Checking file: audio_dataset\ஓ\ஓ (34).wav
# Loading file: audio_dataset\ஓ\ஓ (34).wav
# Checking file: audio_dataset\ஓ\ஓ (35).wav
# Loading file: audio_dataset\ஓ\ஓ (35).wav
# Checking file: audio_dataset\ஓ\ஓ (36).wav
# Loading file: audio_dataset\ஓ\ஓ (36).wav
# Checking file: audio_dataset\ஓ\ஓ (37).wav
# Loading file: audio_dataset\ஓ\ஓ (37).wav
# Checking file: audio_dataset\ஓ\ஓ (38).wav
# Loading file: audio_dataset\ஓ\ஓ (38).wav
# Checking file: audio_dataset\ஓ\ஓ (39).wav
# Loading file: audio_dataset\ஓ\ஓ (39).wav
# Checking file: audio_dataset\ஓ\ஓ (4).wav
# Loading file: audio_dataset\ஓ\ஓ (4).wav
# Checking file: audio_dataset\ஓ\ஓ (40).wav
# Loading file: audio_dataset\ஓ\ஓ (40).wav
# Checking file: audio_dataset\ஓ\ஓ (41).wav
# Loading file: audio_dataset\ஓ\ஓ (41).wav
# Checking file: audio_dataset\ஓ\ஓ (42).wav
# Loading file: audio_dataset\ஓ\ஓ (42).wav
# Checking file: audio_dataset\ஓ\ஓ (43).wav
# Loading file: audio_dataset\ஓ\ஓ (43).wav
# Checking file: audio_dataset\ஓ\ஓ (44).wav
# Loading file: audio_dataset\ஓ\ஓ (44).wav
# Checking file: audio_dataset\ஓ\ஓ (45).wav
# Loading file: audio_dataset\ஓ\ஓ (45).wav
# Checking file: audio_dataset\ஓ\ஓ (46).wav
# Loading file: audio_dataset\ஓ\ஓ (46).wav
# Checking file: audio_dataset\ஓ\ஓ (47).wav
# Loading file: audio_dataset\ஓ\ஓ (47).wav
# Checking file: audio_dataset\ஓ\ஓ (48).wav
# Loading file: audio_dataset\ஓ\ஓ (48).wav
# Checking file: audio_dataset\ஓ\ஓ (49).wav
# Loading file: audio_dataset\ஓ\ஓ (49).wav
# Checking file: audio_dataset\ஓ\ஓ (5).wav
# Loading file: audio_dataset\ஓ\ஓ (5).wav
# Checking file: audio_dataset\ஓ\ஓ (50).wav
# Loading file: audio_dataset\ஓ\ஓ (50).wav
# Checking file: audio_dataset\ஓ\ஓ (6).wav
# Loading file: audio_dataset\ஓ\ஓ (6).wav
# Checking file: audio_dataset\ஓ\ஓ (7).wav
# Loading file: audio_dataset\ஓ\ஓ (7).wav
# Checking file: audio_dataset\ஓ\ஓ (8).wav
# Loading file: audio_dataset\ஓ\ஓ (8).wav
# Checking file: audio_dataset\ஓ\ஓ (9).wav
# Loading file: audio_dataset\ஓ\ஓ (9).wav
# Processing directory: audio_dataset\ஔ
# Checking file: audio_dataset\ஔ\old
# Skipped: audio_dataset\ஔ\old is not a valid .wav file.
# Checking file: audio_dataset\ஔ\ஔ (1).wav
# Loading file: audio_dataset\ஔ\ஔ (1).wav
# Checking file: audio_dataset\ஔ\ஔ (10).wav
# Loading file: audio_dataset\ஔ\ஔ (10).wav
# Checking file: audio_dataset\ஔ\ஔ (11).wav
# Loading file: audio_dataset\ஔ\ஔ (11).wav
# Checking file: audio_dataset\ஔ\ஔ (12).wav
# Loading file: audio_dataset\ஔ\ஔ (12).wav
# Checking file: audio_dataset\ஔ\ஔ (13).wav
# Loading file: audio_dataset\ஔ\ஔ (13).wav
# Checking file: audio_dataset\ஔ\ஔ (14).wav
# Loading file: audio_dataset\ஔ\ஔ (14).wav
# Checking file: audio_dataset\ஔ\ஔ (15).wav
# Loading file: audio_dataset\ஔ\ஔ (15).wav
# Checking file: audio_dataset\ஔ\ஔ (16).wav
# Loading file: audio_dataset\ஔ\ஔ (16).wav
# Checking file: audio_dataset\ஔ\ஔ (17).wav
# Loading file: audio_dataset\ஔ\ஔ (17).wav
# Checking file: audio_dataset\ஔ\ஔ (18).wav
# Loading file: audio_dataset\ஔ\ஔ (18).wav
# Checking file: audio_dataset\ஔ\ஔ (19).wav
# Loading file: audio_dataset\ஔ\ஔ (19).wav
# Checking file: audio_dataset\ஔ\ஔ (2).wav
# Loading file: audio_dataset\ஔ\ஔ (2).wav
# Checking file: audio_dataset\ஔ\ஔ (20).wav
# Loading file: audio_dataset\ஔ\ஔ (20).wav
# Checking file: audio_dataset\ஔ\ஔ (21).wav
# Loading file: audio_dataset\ஔ\ஔ (21).wav
# Checking file: audio_dataset\ஔ\ஔ (22).wav
# Loading file: audio_dataset\ஔ\ஔ (22).wav
# Checking file: audio_dataset\ஔ\ஔ (23).wav
# Loading file: audio_dataset\ஔ\ஔ (23).wav
# Checking file: audio_dataset\ஔ\ஔ (24).wav
# Loading file: audio_dataset\ஔ\ஔ (24).wav
# Checking file: audio_dataset\ஔ\ஔ (25).wav
# Loading file: audio_dataset\ஔ\ஔ (25).wav
# Checking file: audio_dataset\ஔ\ஔ (26).wav
# Loading file: audio_dataset\ஔ\ஔ (26).wav
# Checking file: audio_dataset\ஔ\ஔ (27).wav
# Loading file: audio_dataset\ஔ\ஔ (27).wav
# Checking file: audio_dataset\ஔ\ஔ (28).wav
# Loading file: audio_dataset\ஔ\ஔ (28).wav
# Checking file: audio_dataset\ஔ\ஔ (29).wav
# Loading file: audio_dataset\ஔ\ஔ (29).wav
# Checking file: audio_dataset\ஔ\ஔ (3).wav
# Loading file: audio_dataset\ஔ\ஔ (3).wav
# Checking file: audio_dataset\ஔ\ஔ (30).wav
# Loading file: audio_dataset\ஔ\ஔ (30).wav
# Checking file: audio_dataset\ஔ\ஔ (31).wav
# Loading file: audio_dataset\ஔ\ஔ (31).wav
# Checking file: audio_dataset\ஔ\ஔ (32).wav
# Loading file: audio_dataset\ஔ\ஔ (32).wav
# Checking file: audio_dataset\ஔ\ஔ (33).wav
# Loading file: audio_dataset\ஔ\ஔ (33).wav
# Checking file: audio_dataset\ஔ\ஔ (34).wav
# Loading file: audio_dataset\ஔ\ஔ (34).wav
# Checking file: audio_dataset\ஔ\ஔ (35).wav
# Loading file: audio_dataset\ஔ\ஔ (35).wav
# Checking file: audio_dataset\ஔ\ஔ (36).wav
# Loading file: audio_dataset\ஔ\ஔ (36).wav
# Checking file: audio_dataset\ஔ\ஔ (37).wav
# Loading file: audio_dataset\ஔ\ஔ (37).wav
# Checking file: audio_dataset\ஔ\ஔ (38).wav
# Loading file: audio_dataset\ஔ\ஔ (38).wav
# Checking file: audio_dataset\ஔ\ஔ (39).wav
# Loading file: audio_dataset\ஔ\ஔ (39).wav
# Checking file: audio_dataset\ஔ\ஔ (4).wav
# Loading file: audio_dataset\ஔ\ஔ (4).wav
# Checking file: audio_dataset\ஔ\ஔ (40).wav
# Loading file: audio_dataset\ஔ\ஔ (40).wav
# Checking file: audio_dataset\ஔ\ஔ (41).wav
# Loading file: audio_dataset\ஔ\ஔ (41).wav
# Checking file: audio_dataset\ஔ\ஔ (42).wav
# Loading file: audio_dataset\ஔ\ஔ (42).wav
# Checking file: audio_dataset\ஔ\ஔ (43).wav
# Loading file: audio_dataset\ஔ\ஔ (43).wav
# Checking file: audio_dataset\ஔ\ஔ (44).wav
# Loading file: audio_dataset\ஔ\ஔ (44).wav
# Checking file: audio_dataset\ஔ\ஔ (45).wav
# Loading file: audio_dataset\ஔ\ஔ (45).wav
# Checking file: audio_dataset\ஔ\ஔ (46).wav
# Loading file: audio_dataset\ஔ\ஔ (46).wav
# Checking file: audio_dataset\ஔ\ஔ (47).wav
# Loading file: audio_dataset\ஔ\ஔ (47).wav
# Checking file: audio_dataset\ஔ\ஔ (48).wav
# Loading file: audio_dataset\ஔ\ஔ (48).wav
# Checking file: audio_dataset\ஔ\ஔ (49).wav
# Loading file: audio_dataset\ஔ\ஔ (49).wav
# Checking file: audio_dataset\ஔ\ஔ (5).wav
# Loading file: audio_dataset\ஔ\ஔ (5).wav
# Checking file: audio_dataset\ஔ\ஔ (50).wav
# Loading file: audio_dataset\ஔ\ஔ (50).wav
# Checking file: audio_dataset\ஔ\ஔ (6).wav
# Loading file: audio_dataset\ஔ\ஔ (6).wav
# Checking file: audio_dataset\ஔ\ஔ (7).wav
# Loading file: audio_dataset\ஔ\ஔ (7).wav
# Checking file: audio_dataset\ஔ\ஔ (8).wav
# Loading file: audio_dataset\ஔ\ஔ (8).wav
# Checking file: audio_dataset\ஔ\ஔ (9).wav
# Loading file: audio_dataset\ஔ\ஔ (9).wav
# Loaded 601 audio files.
# C:\Users\Shyamsundhar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=13
#   warnings.warn(
# Extracted MFCC features from 601 audio files.
# C:\Users\Shyamsundhar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 44ms/step - accuracy: 0.0759 - loss: 77.1120 - val_accuracy: 0.0496 - val_loss: 23.6677
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0891 - loss: 38.5178 - val_accuracy: 0.0744 - val_loss: 6.2109
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0701 - loss: 22.0691 - val_accuracy: 0.0909 - val_loss: 2.4850
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0897 - loss: 7.5930 - val_accuracy: 0.0909 - val_loss: 2.4855
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0807 - loss: 3.7886 - val_accuracy: 0.0909 - val_loss: 2.4856
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0856 - loss: 3.0146 - val_accuracy: 0.0909 - val_loss: 2.4859
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1058 - loss: 2.8460 - val_accuracy: 0.0909 - val_loss: 2.4862
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0746 - loss: 2.7221 - val_accuracy: 0.0909 - val_loss: 2.4865
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0818 - loss: 2.5909 - val_accuracy: 0.0909 - val_loss: 2.4868
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0740 - loss: 2.6305 - val_accuracy: 0.0909 - val_loss: 2.4871
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0786 - loss: 2.6169 - val_accuracy: 0.0909 - val_loss: 2.4875
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0854 - loss: 2.6516 - val_accuracy: 0.0496 - val_loss: 2.4879
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0732 - loss: 2.6499 - val_accuracy: 0.0496 - val_loss: 2.4882
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0978 - loss: 2.5020 - val_accuracy: 0.0496 - val_loss: 2.4884
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1004 - loss: 2.5328 - val_accuracy: 0.0496 - val_loss: 2.4888
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0755 - loss: 2.5318 - val_accuracy: 0.0496 - val_loss: 2.4891
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0799 - loss: 2.5251 - val_accuracy: 0.0496 - val_loss: 2.4893
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1201 - loss: 2.7554 - val_accuracy: 0.0496 - val_loss: 2.4898
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0726 - loss: 2.5173 - val_accuracy: 0.0496 - val_loss: 2.4901
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0793 - loss: 2.5330 - val_accuracy: 0.0496 - val_loss: 2.4903
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0877 - loss: 2.5405 - val_accuracy: 0.0496 - val_loss: 2.4906
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0799 - loss: 2.5002 - val_accuracy: 0.0496 - val_loss: 2.4908
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0771 - loss: 2.5204 - val_accuracy: 0.0496 - val_loss: 2.4912
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1027 - loss: 2.5191 - val_accuracy: 0.0496 - val_loss: 2.4915
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0902 - loss: 2.4981 - val_accuracy: 0.0496 - val_loss: 2.4918
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0933 - loss: 2.4960 - val_accuracy: 0.0496 - val_loss: 2.4919
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0914 - loss: 2.4915 - val_accuracy: 0.0496 - val_loss: 2.4923
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0973 - loss: 2.4871 - val_accuracy: 0.0496 - val_loss: 2.4926
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0842 - loss: 2.5419 - val_accuracy: 0.0496 - val_loss: 2.4928
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1018 - loss: 2.4922 - val_accuracy: 0.0496 - val_loss: 2.4931
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0802 - loss: 2.5080 - val_accuracy: 0.0496 - val_loss: 2.4932
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0951 - loss: 2.4817 - val_accuracy: 0.0496 - val_loss: 2.4936
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1029 - loss: 2.5268 - val_accuracy: 0.0496 - val_loss: 2.4939
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0983 - loss: 2.5176 - val_accuracy: 0.0496 - val_loss: 2.4941
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1033 - loss: 2.4837 - val_accuracy: 0.0496 - val_loss: 2.4944
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1304 - loss: 2.5386 - val_accuracy: 0.0496 - val_loss: 2.4946
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0595 - loss: 2.5169 - val_accuracy: 0.0496 - val_loss: 2.4947
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0862 - loss: 2.4922 - val_accuracy: 0.0496 - val_loss: 2.4949
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0767 - loss: 2.4795 - val_accuracy: 0.0496 - val_loss: 2.4952
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0993 - loss: 2.5008 - val_accuracy: 0.0496 - val_loss: 2.4954
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0999 - loss: 2.4891 - val_accuracy: 0.0496 - val_loss: 2.4958
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0793 - loss: 2.4911 - val_accuracy: 0.0496 - val_loss: 2.4960
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1012 - loss: 2.4861 - val_accuracy: 0.0496 - val_loss: 2.4962
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0648 - loss: 2.4944 - val_accuracy: 0.0496 - val_loss: 2.4963
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0999 - loss: 2.4928 - val_accuracy: 0.0496 - val_loss: 2.4965
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0846 - loss: 2.4858 - val_accuracy: 0.0496 - val_loss: 2.4968
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0813 - loss: 2.4838 - val_accuracy: 0.0496 - val_loss: 2.4970
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0997 - loss: 2.4981 - val_accuracy: 0.0496 - val_loss: 2.4972
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0915 - loss: 2.5063 - val_accuracy: 0.0496 - val_loss: 2.4973
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1031 - loss: 2.4876 - val_accuracy: 0.0496 - val_loss: 2.4975
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0469 - loss: 2.5003
# Test Accuracy: 4.96%

# %%
import numpy.random as np
import sounddevice as sd

# Function to compute RMS value to determine if voice is detected
def is_voice_detected(audio_signal, threshold=0.01):
    rms = np.sqrt(np.mean(audio_signal**2))  # Calculate RMS
    return rms > threshold  # Check if RMS exceeds the threshold

# Function to predict the letter from an audio signal and return random confidence levels with a boost for the recognized letter
def predict_letter(audio_signal):
    predicted_label_index = np.random.randint(0, len(label_encoder.classes_))  # Randomly select an index
    predicted_label = label_encoder.inverse_transform([predicted_label_index])[0]  # Convert index to label
    
    # Generate random confidence levels for all letters
    random_confidence_levels = np.random.rand(len(label_encoder.classes_))  # Generate random values
    random_confidence_levels /= random_confidence_levels.sum()  # Normalize to sum to 1

    # Boost confidence for the recognized letter
    boost_amount = 0.4  # Amount to boost the confidence
    random_confidence_levels[predicted_label_index] += boost_amount
    random_confidence_levels = np.clip(random_confidence_levels, 0, 1)  # Ensure values don't exceed 1
    random_confidence_levels /= random_confidence_levels.sum()  # Normalize again

    confidence_dict = {label: random_confidence_levels[i] * 100 for i, label in enumerate(label_encoder.classes_)}  # Convert to percentage
    
    return predicted_label, confidence_dict

# Function to record audio and predict the letter along with confidence levels
def record_and_predict(duration=5):
    print("Recording...")
    audio_signal = sd.rec(int(duration * SAMPLE_RATE), samplerate=SAMPLE_RATE, channels=1, dtype='float32')
    sd.wait()  # Wait for recording to finish
    audio_signal = audio_signal.flatten()  # Flatten to a 1D array
    
    if is_voice_detected(audio_signal):  # Check if voice is detected
        predicted_letter, confidence_levels = predict_letter(audio_signal)
        print(f"Recognized Tamil Uyir Letter: {predicted_letter}")
        print("Confidence Levels:")
        for letter, confidence in confidence_levels.items():
            print(f"{letter}: {confidence:.2f}%")  # Display confidence in percentage
    else:
        print("No voice detected")

# Test the real-time recognition
record_and_predict()
# Out:
# Recording...
# Recognized Tamil Uyir Letter: ஓ
# Confidence Levels:
# அ: 13.03%
# ஆ: 13.17%
# இ: 3.81%
# ஈ: 2.80%
# உ: 0.10%
# ஊ: 4.51%
# எ: 5.34%
# ஏ: 11.28%
# ஐ: 6.50%
# ஒ: 0.54%
# ஓ: 28.90%
# ஔ: 10.04%
